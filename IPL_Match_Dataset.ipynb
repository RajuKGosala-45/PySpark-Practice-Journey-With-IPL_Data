# %% [markdown]
# <a href="https://colab.research.google.com/github/RajuKGosala-45/PySpark-Practice-Journey-With-IPL_Data/blob/main/IPL_Match_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PySpark Setup (for Colab)**

# %%
# PySpark Setup (for Colab)
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !pip install -q pyspark

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["PATH"] += os.pathsep + os.path.join(os.environ["JAVA_HOME"], "bin")

# %% [markdown]
# # **Day 34 -Advanced Pyspark Practices Using IPL_Match_Data**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import*
from pyspark.sql.types import*
from pyspark.sql.window import Window

spark=SparkSession.builder.appName("IPL_Match_Data_Analysis").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)

# Ipl matches Data Info
print("---Matches_Data Schema---")
matches_df.printSchema()
print("---Matches_Data")
matches_df.show()
print("---Matches_Data Describe")
matches_df.describe().show()

# Players Data Info
print("---Players_Data Schema---")
players_df.printSchema()
print("---Players_Data")
players_df.show()
print("---Players_Data Describe")
players_df.describe().show()

# Teams_Data Info
print("---Teams_Data Schema---")
teams_df.printSchema()
print("---Teams_Data")
teams_df.show()
print("---Teams_Data Describe")
teams_df.describe().show()
# Out:
# ---Matches_Data Schema---
# root
#  |-- match_id: integer (nullable = true)
#  |-- season_id: integer (nullable = true)
#  |-- balls_per_over: integer (nullable = true)
#  |-- city: string (nullable = true)
#  |-- match_date: string (nullable = true)
#  |-- event_name: string (nullable = true)
#  |-- match_number: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- match_type: string (nullable = true)
#  |-- format: timestamp (nullable = true)
#  |-- overs: integer (nullable = true)
#  |-- season: string (nullable = true)
#  |-- team_type: string (nullable = true)
#  |-- venue: string (nullable = true)
#  |-- toss_winner: string (nullable = true)
#  |-- team1: string (nullable = true)
#  |-- team2: string (nullable = true)
#  |-- toss_decision: string (nullable = true)
#  |-- match_winner: string (nullable = true)
#  |-- win_by_runs: string (nullable = true)
#  |-- win_by_wickets: string (nullable = true)
#  |-- player_of_match: string (nullable = true)
#  |-- result: string (nullable = true)
#  |-- stage: string (nullable = true)
#
# ---Matches_Data
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+
# |match_id|season_id|balls_per_over|     city|match_date|          event_name|match_number|gender|match_type|             format|overs|season|team_type|               venue|         toss_winner|               team1|               team2|toss_decision|        match_winner|win_by_runs|win_by_wickets|player_of_match|result|stage|
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+
# |  335982|     2008|             6|Bangalore|18-04-2008|Indian Premier Le...|           1|  male|       T20|2025-11-14 20:00:00|   20|  2008|     club|M Chinnaswamy Sta...|Royal Challengers...|Royal Challengers...|Kolkata Knight Ri...|        field|Kolkata Knight Ri...|        140|          NULL|             46|   win| NULL|
# | 1082591|     2017|             6|Hyderabad|05-04-2017|Indian Premier Le...|           1|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Rajiv Gandhi Inte...|Royal Challengers...| Sunrisers Hyderabad|Royal Challengers...|        field| Sunrisers Hyderabad|         35|          NULL|             15|   win| NULL|
# | 1082592|     2017|             6|     Pune|06-04-2017|Indian Premier Le...|           2|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Maharashtra Crick...|Rising Pune Super...|Rising Pune Super...|      Mumbai Indians|        field|Rising Pune Super...|       NULL|             7|             36|   win| NULL|
# | 1082593|     2017|             6|   Rajkot|07-04-2017|Indian Premier Le...|           3|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Saurashtra Cricke...|Kolkata Knight Ri...|       Gujarat Lions|Kolkata Knight Ri...|        field|Kolkata Knight Ri...|       NULL|            10|             57|   win| NULL|
# | 1082594|     2017|             6|   Indore|08-04-2017|Indian Premier Le...|           4|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Holkar Cricket St...|        Punjab Kings|        Punjab Kings|Rising Pune Super...|        field|        Punjab Kings|       NULL|             6|             71|   win| NULL|
# | 1082595|     2017|             6|Bengaluru|08-04-2017|Indian Premier Le...|           5|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|M.Chinnaswamy Sta...|Royal Challengers...|Royal Challengers...|      Delhi Capitals|          bat|Royal Challengers...|         15|          NULL|              4|   win| NULL|
# | 1082596|     2017|             6|Hyderabad|09-04-2017|Indian Premier Le...|           6|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Rajiv Gandhi Inte...| Sunrisers Hyderabad| Sunrisers Hyderabad|       Gujarat Lions|        field| Sunrisers Hyderabad|       NULL|             9|             22|   win| NULL|
# | 1082597|     2017|             6|   Mumbai|09-04-2017|Indian Premier Le...|           7|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|    Wankhede Stadium|      Mumbai Indians|      Mumbai Indians|Kolkata Knight Ri...|        field|      Mumbai Indians|       NULL|             4|             26|   win| NULL|
# | 1082598|     2017|             6|   Indore|10-04-2017|Indian Premier Le...|           8|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Holkar Cricket St...|Royal Challengers...|        Punjab Kings|Royal Challengers...|          bat|        Punjab Kings|       NULL|             8|             70|   win| NULL|
# | 1082599|     2017|             6|     Pune|11-04-2017|Indian Premier Le...|           9|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Maharashtra Crick...|Rising Pune Super...|Rising Pune Super...|      Delhi Capitals|        field|      Delhi Capitals|         97|          NULL|            180|   win| NULL|
# | 1082600|     2017|             6|   Mumbai|12-04-2017|Indian Premier Le...|          10|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|    Wankhede Stadium|      Mumbai Indians|      Mumbai Indians| Sunrisers Hyderabad|        field|      Mumbai Indians|       NULL|             4|             33|   win| NULL|
# | 1082601|     2017|             6|  Kolkata|13-04-2017|Indian Premier Le...|          11|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|        Eden Gardens|Kolkata Knight Ri...|Kolkata Knight Ri...|        Punjab Kings|        field|Kolkata Knight Ri...|       NULL|             8|             65|   win| NULL|
# | 1082602|     2017|             6|Bangalore|14-04-2017|Indian Premier Le...|          12|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|M Chinnaswamy Sta...|      Mumbai Indians|Royal Challengers...|      Mumbai Indians|        field|      Mumbai Indians|       NULL|             4|             29|   win| NULL|
# | 1082603|     2017|             6|   Rajkot|14-04-2017|Indian Premier Le...|          13|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Saurashtra Cricke...|       Gujarat Lions|       Gujarat Lions|Rising Pune Super...|        field|       Gujarat Lions|       NULL|             7|            351|   win| NULL|
# | 1082604|     2017|             6|  Kolkata|15-04-2017|Indian Premier Le...|          14|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|        Eden Gardens| Sunrisers Hyderabad|Kolkata Knight Ri...| Sunrisers Hyderabad|        field|Kolkata Knight Ri...|         17|          NULL|             58|   win| NULL|
# | 1082605|     2017|             6|    Delhi|15-04-2017|Indian Premier Le...|          15|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|    Feroz Shah Kotla|      Delhi Capitals|      Delhi Capitals|        Punjab Kings|          bat|      Delhi Capitals|         51|          NULL|            258|   win| NULL|
# | 1082606|     2017|             6|   Mumbai|16-04-2017|Indian Premier Le...|          16|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|    Wankhede Stadium|      Mumbai Indians|      Mumbai Indians|       Gujarat Lions|        field|      Mumbai Indians|       NULL|             6|             26|   win| NULL|
# | 1082607|     2017|             6|Bangalore|16-04-2017|Indian Premier Le...|          17|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|M Chinnaswamy Sta...|Royal Challengers...|Royal Challengers...|Rising Pune Super...|        field|Rising Pune Super...|         27|          NULL|             37|   win| NULL|
# | 1082608|     2017|             6|    Delhi|17-04-2017|Indian Premier Le...|          18|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|    Feroz Shah Kotla|      Delhi Capitals|      Delhi Capitals|Kolkata Knight Ri...|          bat|Kolkata Knight Ri...|       NULL|             4|            471|   win| NULL|
# | 1082609|     2017|             6|Hyderabad|17-04-2017|Indian Premier Le...|          19|  male|       T20|2025-11-14 20:00:00|   20|  2017|     club|Rajiv Gandhi Inte...|        Punjab Kings| Sunrisers Hyderabad|        Punjab Kings|        field| Sunrisers Hyderabad|          5|          NULL|             20|   win| NULL|
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+
# only showing top 20 rows
#
# ---Matches_Data Describe
# +-------+------------------+------------------+--------------+-------------+----------+--------------------+------------------+------+----------+-----+------------------+---------+--------------------+-------------------+-------------------+-------------------+-------------+-------------------+------------------+------------------+-----------------+---------+-----------+
# |summary|          match_id|         season_id|balls_per_over|         city|match_date|          event_name|      match_number|gender|match_type|overs|            season|team_type|               venue|        toss_winner|              team1|              team2|toss_decision|       match_winner|       win_by_runs|    win_by_wickets|  player_of_match|   result|      stage|
# +-------+------------------+------------------+--------------+-------------+----------+--------------------+------------------+------+----------+-----+------------------+---------+--------------------+-------------------+-------------------+-------------------+-------------+-------------------+------------------+------------------+-----------------+---------+-----------+
# |  count|              1169|              1169|          1169|         1169|      1169|                1169|              1169|  1169|      1169| 1169|              1169|     1169|                1169|               1168|               1169|               1169|         1168|               1161|              1169|              1169|             1168|     1169|          4|
# |   mean| 940934.2763045338|2016.6877673224978|           6.0|         NULL|      NULL|                NULL| 31.70518653321201|  NULL|      NULL| 20.0|2016.5085662759243|     NULL|                NULL|               NULL|               NULL|               NULL|         NULL|               NULL|30.295668549905837|               6.2|3274.304048234281|     NULL|       NULL|
# | stddev|382077.65224841493| 5.253100443983451|           0.0|         NULL|      NULL|                NULL|18.518303858919094|  NULL|      NULL|  0.0|5.3350865573433595|     NULL|                NULL|               NULL|               NULL|               NULL|         NULL|               NULL|26.866707322171386|1.8521929954808012|5857.156934459648|     NULL|       NULL|
# |    min|            335982|              2008|             6|    Abu Dhabi|01-04-2010|Indian Premier Le...|                 1|  male|Eliminator|   20|              2008|     club|Arun Jaitley Stadium|Chennai Super Kings|Chennai Super Kings|Chennai Super Kings|          bat|Chennai Super Kings|                 1|                 1|                1|no result| Eliminator|
# |    max|           1589258|              2025|             6|Visakhapatnam|31-10-2020|Indian Premier Le...|              NULL|  male|       T20|   20|              2025|     club|Zayed Cricket Sta...|Sunrisers Hyderabad|Sunrisers Hyderabad|Sunrisers Hyderabad|        field|Sunrisers Hyderabad|              NULL|              NULL|             NULL|      win|Qualifier 2|
# +-------+------------------+------------------+--------------+-------------+----------+--------------------+------------------+------+----------+-----+------------------+---------+--------------------+-------------------+-------------------+-------------------+-------------+-------------------+------------------+------------------+-----------------+---------+-----------+
#
# ---Players_Data Schema---
# root
#  |-- player_id: integer (nullable = true)
#  |-- player_name: string (nullable = true)
#  |-- bat_style: string (nullable = true)
#  |-- bowl_style: string (nullable = true)
#  |-- field_pos: string (nullable = true)
#  |-- player_full_name: string (nullable = true)
#  |-- player_name2: string (nullable = true)
#  |-- player_image: string (nullable = true)
#
# ---Players_Data
# +---------+-------------+--------------+--------------------+---------+--------------------+------------------+--------------------+
# |player_id|  player_name|     bat_style|          bowl_style|field_pos|    player_full_name|      player_name2|        player_image|
# +---------+-------------+--------------+--------------------+---------+--------------------+------------------+--------------------+
# |     6730|  Mohsin Khan| Left hand Bat|Left arm Medium fast|     NULL|         Mohsin Khan|       Mohsin Khan|                NULL|
# |       22|  Rashid Khan|Right hand Bat|     Legbreak Googly|         |   Rashid Khan Arman|       Rashid Khan|https://www.espnc...|
# |      590|     K Rabada| Left hand Bat|      Right arm Fast|         |       Kagiso Rabada|     Kagiso Rabada|https://ipl-stats...|
# |     1424|      SN Khan|Right hand Bat|            Legbreak|         |Sarfaraz Naushad ...|  Sarfaraz Naushad|                NULL|
# |      963|   MN Samuels|Right hand Bat|  Right arm Offbreak|         |Marlon Nathaniel ...|  Marlon Nathaniel|                NULL|
# |       53|    SB Jakati| Left hand Bat|Slow Left arm Ort...|         |Shadab Bashir Jakati|     Shadab Bashir|                NULL|
# |       12|    DA Warner| Left hand Bat|            Legbreak|         | David Andrew Warner|      David Andrew|https://ipl-stats...|
# |       73|   MP Stoinis|Right hand Bat|    Right arm Medium|         |Marcus Peter Stoinis|      Marcus Peter|                NULL|
# |     1119|    R Tewatia| Left hand Bat|            Legbreak|         |       Rahul Tewatia|     Rahul Tewatia|https://www.espnc...|
# |      268|  RA Tripathi|Right hand Bat|    Right arm Medium|         | Rahul Ajay Tripathi|        Rahul Ajay|                NULL|
# |      163|    RD Chahar|Right hand Bat|     Legbreak Googly|         | Rahul Desraj Chahar|      Rahul Desraj|                NULL|
# |      186|     S Nadeem|Right hand Bat|Slow Left arm Ort...|         |      Shahbaz Nadeem|    Shahbaz Nadeem|                NULL|
# |       59|    MK Pandey|Right hand Bat|    Right arm Medium|         |Manish Krishnanan...|Manish Krishnanand|                NULL|
# |      531|KS Williamson|Right hand Bat|  Right arm Offbreak|         |Kane Stuart Willi...|       Kane Stuart|https://ipl-stats...|
# |       56|    G Gambhir| Left hand Bat|            Legbreak|         |      Gautam Gambhir|    Gautam Gambhir|https://documents...|
# |       39|    MK Tiwary|Right hand Bat|     Legbreak Googly|         |  Manoj Kumar Tiwary|       Manoj Kumar|                NULL|
# |       68|      M Vohra|Right hand Bat|    Right arm Medium|         |         Manan Vohra|       Manan Vohra|                NULL|
# |      638|     NB Singh|Right hand Bat|    Right arm Medium|         |  Nathu Bharat Singh|      Nathu Bharat|                NULL|
# |       40|     R Bhatia|Right hand Bat|Right arm Medium ...|         |        Rajat Bhatia|      Rajat Bhatia|                NULL|
# |     1233|    SS Tiwary| Left hand Bat|                    |         |Saurabh Sunil Tiwary|     Saurabh Sunil|                NULL|
# +---------+-------------+--------------+--------------------+---------+--------------------+------------------+--------------------+
# only showing top 20 rows
#
# ---Players_Data Describe
# +-------+------------------+--------------+--------------+--------------------+------------+----------------+--------------+--------------------+
# |summary|         player_id|   player_name|     bat_style|          bowl_style|   field_pos|player_full_name|  player_name2|        player_image|
# +-------+------------------+--------------+--------------+--------------------+------------+----------------+--------------+--------------------+
# |  count|               772|           772|           772|                 772|         772|             772|           772|                 134|
# |   mean|11085.305699481865|          NULL|          NULL|                NULL|        NULL|            NULL|          NULL|                NULL|
# | stddev|11339.197704576356|          NULL|          NULL|                NULL|        NULL|            NULL|          NULL|                NULL|
# |    min|                 1|A Ashish Reddy| Left hand Bat|                    |            |   Aakash Chopra| Aakash Chopra|https://cricclubs...|
# |    max|             43954|Zeeshan Ansari|Right hand Bat|Slow Left arm Ort...|Wicketkeeper|  Zeeshan Ansari|Zeeshan Ansari|https://www.espnc...|
# +-------+------------------+--------------+--------------+--------------------+------------+----------------+--------------+--------------------+
#
# ---Teams_Data Schema---
# root
#  |-- team_id: integer (nullable = true)
#  |-- team_name: string (nullable = true)
#  |-- team_name_short: string (nullable = true)
#  |-- image_url: string (nullable = true)
#
# ---Teams_Data
# +-------+--------------------+---------------+--------------------+
# |team_id|           team_name|team_name_short|           image_url|
# +-------+--------------------+---------------+--------------------+
# |      1|Royal Challengers...|            RCB|https://documents...|
# |      2| Sunrisers Hyderabad|            SRH|https://documents...|
# |      3|      Mumbai Indians|             MI|https://documents...|
# |      4|Rising Pune Super...|            RPS|https://ipl-stats...|
# |      5|       Gujarat Lions|             GL|https://ipl-stats...|
# |      6|Kolkata Knight Ri...|            KKR|https://documents...|
# |    129| Chennai Super Kings|            CSK|https://documents...|
# |    134|    Rajasthan Royals|             RR|https://1000logos...|
# |    252|      Delhi Capitals|             DC|https://documents...|
# |    494|        Punjab Kings|             PK|https://documents...|
# |    614|Lucknow Super Giants|            LSG|https://documents...|
# |    615|      Gujarat Titans|             GT|https://documents...|
# |   1068|     Deccan Chargers|            DEC|https://ipl-stats...|
# |   1414|Kochi Tuskers Kerala|            KTK|https://ipl-stats...|
# |   1419|       Pune Warriors|            PWI|https://ipl-stats...|
# |   3604|Rising Pune Super...|            RPS|https://ipl-stats...|
# +-------+--------------------+---------------+--------------------+
#
# ---Teams_Data Describe
# +-------+-----------------+-------------------+---------------+--------------------+
# |summary|          team_id|          team_name|team_name_short|           image_url|
# +-------+-----------------+-------------------+---------------+--------------------+
# |  count|               16|                 16|             16|                  16|
# |   mean|           610.25|               NULL|           NULL|                NULL|
# | stddev|940.9698897060063|               NULL|           NULL|                NULL|
# |    min|                1|Chennai Super Kings|            CSK|https://1000logos...|
# |    max|             3604|Sunrisers Hyderabad|            SRH|https://ipl-stats...|
# +-------+-----------------+-------------------+---------------+--------------------+

# %% [markdown]
# ## 1.Join Datasets in Pyspark

# %%
Ipl_data= matches_df.join(teams_df, matches_df["team1"] == teams_df["team_name"], "left")\
                    .join(players_df, matches_df["player_of_match"] == players_df["player_id"], "left")
Ipl_data.show()
# Out:
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+-------+--------------------+---------------+--------------------+---------+---------------+--------------+--------------------+--------------------+--------------------+-------------------+--------------------+
# |match_id|season_id|balls_per_over|     city|match_date|          event_name|match_number|gender|match_type|             format|overs|season|team_type|               venue|         toss_winner|               team1|               team2|toss_decision|        match_winner|win_by_runs|win_by_wickets|player_of_match|result|stage|team_id|           team_name|team_name_short|           image_url|player_id|    player_name|     bat_style|          bowl_style|           field_pos|    player_full_name|       player_name2|        player_image|
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+-------+--------------------+---------------+--------------------+---------+---------------+--------------+--------------------+--------------------+--------------------+-------------------+--------------------+
# |  335982|     2008|             6|Bangalore|18-04-2008|Indian Premier Le...|           1|  male|       T20|2025-11-13 20:00:00|   20|  2008|     club|M Chinnaswamy Sta...|Royal Challengers...|Royal Challengers...|Kolkata Knight Ri...|        field|Kolkata Knight Ri...|        140|          NULL|             46|   win| NULL|      1|Royal Challengers...|            RCB|https://documents...|       46|    BB McCullum|Right hand Bat|Right arm Medium,...|        Wicketkeeper|Brendon Barrie Mc...|     Brendon Barrie|                NULL|
# | 1082591|     2017|             6|Hyderabad|05-04-2017|Indian Premier Le...|           1|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Rajiv Gandhi Inte...|Royal Challengers...| Sunrisers Hyderabad|Royal Challengers...|        field| Sunrisers Hyderabad|         35|          NULL|             15|   win| NULL|      2| Sunrisers Hyderabad|            SRH|https://documents...|       15|   Yuvraj Singh| Left hand Bat|Slow Left arm Ort...|                    |        Yuvraj Singh|       Yuvraj Singh|                NULL|
# | 1082592|     2017|             6|     Pune|06-04-2017|Indian Premier Le...|           2|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Maharashtra Crick...|Rising Pune Super...|Rising Pune Super...|      Mumbai Indians|        field|Rising Pune Super...|       NULL|             7|             36|   win| NULL|      4|Rising Pune Super...|            RPS|https://ipl-stats...|       36|      SPD Smith|Right hand Bat|     Legbreak Googly|                    |Steven Peter Deve...|       Steven Peter|                NULL|
# | 1082593|     2017|             6|   Rajkot|07-04-2017|Indian Premier Le...|           3|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Saurashtra Cricke...|Kolkata Knight Ri...|       Gujarat Lions|Kolkata Knight Ri...|        field|Kolkata Knight Ri...|       NULL|            10|             57|   win| NULL|      5|       Gujarat Lions|             GL|https://ipl-stats...|       57|        CA Lynn|Right hand Bat|Slow Left arm Ort...|                    |Christopher Austi...| Christopher Austin|                NULL|
# | 1082594|     2017|             6|   Indore|08-04-2017|Indian Premier Le...|           4|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Holkar Cricket St...|        Punjab Kings|        Punjab Kings|Rising Pune Super...|        field|        Punjab Kings|       NULL|             6|             71|   win| NULL|    494|        Punjab Kings|             PK|https://documents...|       71|     GJ Maxwell|Right hand Bat|  Right arm Offbreak|                    | Glenn James Maxwell|        Glenn James|https://ipl-stats...|
# | 1082595|     2017|             6|Bengaluru|08-04-2017|Indian Premier Le...|           5|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|M.Chinnaswamy Sta...|Royal Challengers...|Royal Challengers...|      Delhi Capitals|          bat|Royal Challengers...|         15|          NULL|              4|   win| NULL|      1|Royal Challengers...|            RCB|https://documents...|        4|      KM Jadhav|Right hand Bat|  Right arm Offbreak|                    |Kedar Mahadav Jadhav|      Kedar Mahadav|                NULL|
# | 1082596|     2017|             6|Hyderabad|09-04-2017|Indian Premier Le...|           6|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Rajiv Gandhi Inte...| Sunrisers Hyderabad| Sunrisers Hyderabad|       Gujarat Lions|        field| Sunrisers Hyderabad|       NULL|             9|             22|   win| NULL|      2| Sunrisers Hyderabad|            SRH|https://documents...|       22|    Rashid Khan|Right hand Bat|     Legbreak Googly|                    |   Rashid Khan Arman|        Rashid Khan|https://www.espnc...|
# | 1082597|     2017|             6|   Mumbai|09-04-2017|Indian Premier Le...|           7|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|    Wankhede Stadium|      Mumbai Indians|      Mumbai Indians|Kolkata Knight Ri...|        field|      Mumbai Indians|       NULL|             4|             26|   win| NULL|      3|      Mumbai Indians|             MI|https://documents...|       26|         N Rana| Left hand Bat|Right arm Medium,...|                    |         Nitish Rana|        Nitish Rana|https://www.espnc...|
# | 1082598|     2017|             6|   Indore|10-04-2017|Indian Premier Le...|           8|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Holkar Cricket St...|Royal Challengers...|        Punjab Kings|Royal Challengers...|          bat|        Punjab Kings|       NULL|             8|             70|   win| NULL|    494|        Punjab Kings|             PK|https://documents...|       70|       AR Patel| Left hand Bat|Slow Left arm Ort...|                    |Axar Rajeshbhai P...|    Axar Rajeshbhai|                NULL|
# | 1082599|     2017|             6|     Pune|11-04-2017|Indian Premier Le...|           9|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Maharashtra Crick...|Rising Pune Super...|Rising Pune Super...|      Delhi Capitals|        field|      Delhi Capitals|         97|          NULL|            180|   win| NULL|      4|Rising Pune Super...|            RPS|https://ipl-stats...|      180|      SV Samson|Right hand Bat|                    |        Wicketkeeper|Sanju Viswanath S...|    Sanju Viswanath|                NULL|
# | 1082600|     2017|             6|   Mumbai|12-04-2017|Indian Premier Le...|          10|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|    Wankhede Stadium|      Mumbai Indians|      Mumbai Indians| Sunrisers Hyderabad|        field|      Mumbai Indians|       NULL|             4|             33|   win| NULL|      3|      Mumbai Indians|             MI|https://documents...|       33|      JJ Bumrah|Right hand Bat|      Right arm Fast|                    |Jasprit Jasbirsin...|Jasprit Jasbirsingh|                NULL|
# | 1082601|     2017|             6|  Kolkata|13-04-2017|Indian Premier Le...|          11|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|        Eden Gardens|Kolkata Knight Ri...|Kolkata Knight Ri...|        Punjab Kings|        field|Kolkata Knight Ri...|       NULL|             8|             65|   win| NULL|      6|Kolkata Knight Ri...|            KKR|https://documents...|       65|      SP Narine| Left hand Bat|  Right arm Offbreak|                    | Sunil Philip Narine|       Sunil Philip|                NULL|
# | 1082602|     2017|             6|Bangalore|14-04-2017|Indian Premier Le...|          12|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|M Chinnaswamy Sta...|      Mumbai Indians|Royal Challengers...|      Mumbai Indians|        field|      Mumbai Indians|       NULL|             4|             29|   win| NULL|      1|Royal Challengers...|            RCB|https://documents...|       29|     KA Pollard|Right hand Bat|    Right arm Medium|                    |Kieron Adrian Pol...|      Kieron Adrian|                NULL|
# | 1082603|     2017|             6|   Rajkot|14-04-2017|Indian Premier Le...|          13|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Saurashtra Cricke...|       Gujarat Lions|       Gujarat Lions|Rising Pune Super...|        field|       Gujarat Lions|       NULL|             7|            351|   win| NULL|      5|       Gujarat Lions|             GL|https://ipl-stats...|      351|         AJ Tye|Right hand Bat|Right arm Medium ...|                    |    Andrew James Tye|       Andrew James|https://ipl-stats...|
# | 1082604|     2017|             6|  Kolkata|15-04-2017|Indian Premier Le...|          14|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|        Eden Gardens| Sunrisers Hyderabad|Kolkata Knight Ri...| Sunrisers Hyderabad|        field|Kolkata Knight Ri...|         17|          NULL|             58|   win| NULL|      6|Kolkata Knight Ri...|            KKR|https://documents...|       58|     RV Uthappa|Right hand Bat|    Right arm Medium|Occasional Wicket...|  Robin Venu Uthappa|         Robin Venu|https://ipl-stats...|
# | 1082605|     2017|             6|    Delhi|15-04-2017|Indian Premier Le...|          15|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|    Feroz Shah Kotla|      Delhi Capitals|      Delhi Capitals|        Punjab Kings|          bat|      Delhi Capitals|         51|          NULL|            258|   win| NULL|    252|      Delhi Capitals|             DC|https://documents...|      258|    CJ Anderson| Left hand Bat|Left arm Medium fast|                    |Corey James Anderson|        Corey James|                NULL|
# | 1082606|     2017|             6|   Mumbai|16-04-2017|Indian Premier Le...|          16|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|    Wankhede Stadium|      Mumbai Indians|      Mumbai Indians|       Gujarat Lions|        field|      Mumbai Indians|       NULL|             6|             26|   win| NULL|      3|      Mumbai Indians|             MI|https://documents...|       26|         N Rana| Left hand Bat|Right arm Medium,...|                    |         Nitish Rana|        Nitish Rana|https://www.espnc...|
# | 1082607|     2017|             6|Bangalore|16-04-2017|Indian Premier Le...|          17|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|M Chinnaswamy Sta...|Royal Challengers...|Royal Challengers...|Rising Pune Super...|        field|Rising Pune Super...|         27|          NULL|             37|   win| NULL|      1|Royal Challengers...|            RCB|https://documents...|       37|      BA Stokes| Left hand Bat|Right arm Fast me...|                    |Benjamin Andrew S...|    Benjamin Andrew|                NULL|
# | 1082608|     2017|             6|    Delhi|17-04-2017|Indian Premier Le...|          18|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|    Feroz Shah Kotla|      Delhi Capitals|      Delhi Capitals|Kolkata Knight Ri...|          bat|Kolkata Knight Ri...|       NULL|             4|            471|   win| NULL|    252|      Delhi Capitals|             DC|https://documents...|      471|NM Coulter-Nile|Right hand Bat|      Right arm Fast|                    |Nathan Mitchell C...|    Nathan Mitchell|                NULL|
# | 1082609|     2017|             6|Hyderabad|17-04-2017|Indian Premier Le...|          19|  male|       T20|2025-11-13 20:00:00|   20|  2017|     club|Rajiv Gandhi Inte...|        Punjab Kings| Sunrisers Hyderabad|        Punjab Kings|        field| Sunrisers Hyderabad|          5|          NULL|             20|   win| NULL|      2| Sunrisers Hyderabad|            SRH|https://documents...|       20|        B Kumar|Right hand Bat|    Right arm Medium|                    |Bhuvneshwar Kumar...|  Bhuvneshwar Kumar|https://ipl-stats...|
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+-------+--------------------+---------------+--------------------+---------+---------------+--------------+--------------------+--------------------+--------------------+-------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## 2. Aggregations - Top Winning Teams

# %%
team_wins = matches_df.groupBy("match_winner").agg(count("*").alias("total_wins"))\
.orderBy(desc("total_wins"))
team_wins.show(5)
# Out:
# +--------------------+----------+
# |        match_winner|total_wins|
# +--------------------+----------+
# |      Mumbai Indians|       153|
# | Chennai Super Kings|       142|
# |Kolkata Knight Ri...|       135|
# |Royal Challengers...|       133|
# | Sunrisers Hyderabad|       125|
# +--------------------+----------+
# only showing top 5 rows

# %% [markdown]
# ## 3.Player Analysis – Most Player of the Match Awards

# %%
top_players=players_df.join(matches_df, players_df["player_id"] == matches_df["player_of_match"],"inner")\
                      .groupby("player_name").agg(count("*").alias("MOM_Awards"))\
                      .orderBy(desc("MOM_Awards"))
top_players.show(5)
# Out:
# +--------------+----------+
# |   player_name|MOM_Awards|
# +--------------+----------+
# |AB de Villiers|        25|
# |      CH Gayle|        22|
# |     RG Sharma|        21|
# |       V Kohli|        19|
# |     DA Warner|        18|
# +--------------+----------+
# only showing top 5 rows

# %% [markdown]
# ## 4.Use Window Functions – Top 3 Players by Avg Runs

# %%
window_player = Window.orderBy(desc("mom_awards"))
ranked_players = top_players.withColumn("rank", rank().over(window_player))
ranked_players.filter(col("rank") <= 3).show(truncate=False)
# Out:
# +--------------+----------+----+
# |player_name   |MOM_Awards|rank|
# +--------------+----------+----+
# |AB de Villiers|25        |1   |
# |CH Gayle      |22        |2   |
# |RG Sharma     |21        |3   |
# +--------------+----------+----+

# %% [markdown]
# ## 5.Team Performance Summary

# %%
team_performance = matches_df.groupBy("match_winner").agg(
    count("*").alias("Matches_Won"),
    round(avg("win_by_runs"), 2).alias("Avg_Run_Margin"),
    round(avg("win_by_wickets"), 2).alias("Avg_Wicket_Margin")
).orderBy(desc("Matches_Won"))

team_performance.show(10, truncate=False)
# Out:
# +---------------------------+-----------+--------------+-----------------+
# |match_winner               |Matches_Won|Avg_Run_Margin|Avg_Wicket_Margin|
# +---------------------------+-----------+--------------+-----------------+
# |Mumbai Indians             |153        |34.03         |6.24             |
# |Chennai Super Kings        |142        |35.61         |5.93             |
# |Kolkata Knight Riders      |135        |33.49         |6.24             |
# |Royal Challengers Bangalore|133        |33.03         |6.59             |
# |Sunrisers Hyderabad        |125        |26.31         |6.67             |
# |Punjab Kings               |123        |24.21         |6.17             |
# |Delhi Capitals             |121        |25.62         |6.18             |
# |Rajasthan Royals           |116        |30.71         |5.87             |
# |Gujarat Titans             |37         |36.47         |6.05             |
# |Lucknow Super Giants       |30         |22.1          |5.4              |
# +---------------------------+-----------+--------------+-----------------+
# only showing top 10 rows

# %% [markdown]
# # **35.Best Practices of Advanced Joins + Real-World Analysis**

# %% [markdown]
# ### *1.Find the Top 5 Most Dominant Teams (Based on Win %)*

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
spark=SparkSession.builder.appName("IPL_Analytics").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)

ipl_data =matches_df.join(teams_df, matches_df["team1"]== teams_df["team_name"], "left")\
                    .join(players_df, matches_df["player_of_match"]== players_df["player_id"],"left")

team_stats = (
    ipl_data.groupBy("match_winner").agg(
        count("*").alias("wins")
    )
    .join(
        ipl_data.select("team1").union(ipl_data.select("team2"))
              .groupBy("team1").count()
              .withColumnRenamed("team1", "team")
              .withColumnRenamed("count", "total_matches"),
        col("match_winner") == col("team"),
        "inner"
    )
    .withColumn("win_percentage", round((col("wins") / col("total_matches")) * 100, 2))
    .orderBy(col("win_percentage").desc())
)

team_stats.show(5)
# Out:
# +--------------------+----+--------------------+-------------+--------------+
# |        match_winner|wins|                team|total_matches|win_percentage|
# +--------------------+----+--------------------+-------------+--------------+
# |      Gujarat Titans|  37|      Gujarat Titans|           60|         61.67|
# | Chennai Super Kings| 142| Chennai Super Kings|          252|         56.35|
# |      Mumbai Indians| 153|      Mumbai Indians|          277|         55.23|
# |Lucknow Super Giants|  30|Lucknow Super Giants|           58|         51.72|
# |Kolkata Knight Ri...| 135|Kolkata Knight Ri...|          265|         50.94|
# +--------------------+----+--------------------+-------------+--------------+
# only showing top 5 rows

# %% [markdown]
# ### 2.Most Toss Winners vs Actual Match Winners(Correlation Check)

# %%
toss_vs_match =(
    ipl_data.withColumn("toss_match_same",
                        (col("toss_winner") == col("match_winner"))
                        .cast("int"))
)
toss_vs_match.groupBy().avg("toss_match_same").show()
# Out:
# +--------------------+
# |avg(toss_match_same)|
# +--------------------+
# |  0.5150732127476314|
# +--------------------+

# %% [markdown]
# ### 3.strongest cities - Most matches Hosted

# %%
city_df=(
    ipl_data.groupBy("city").count()
    .orderBy(col("count").desc())
)
city_df.show(10)
# Out:
# +----------+-----+
# |      city|count|
# +----------+-----+
# |    Mumbai|  180|
# |   Kolkata|  100|
# |     Delhi|   97|
# |   Chennai|   91|
# | Hyderabad|   83|
# | Bangalore|   65|
# |    Jaipur|   64|
# |Chandigarh|   61|
# |      Pune|   51|
# |      NULL|   51|
# +----------+-----+
# only showing top 10 rows

# %% [markdown]
# ### 4.Top Bowlers Based on Player of Match Awards

# %%
bowler_awards = (
    ipl_data.filter((col("bowl_style").isNotNull()) & (col("bowl_style") != ""))
    .groupBy("player_full_name")
    .count()
    .orderBy(col("count").desc())
)
bowler_awards.show(10, truncate=False)
# Out:
# +-------------------------------+-----+
# |player_full_name               |count|
# +-------------------------------+-----+
# |Abraham Benjamin de Villiers   |25   |
# |Christopher Henry Gayle        |22   |
# |Rohit Gurunath Sharma          |21   |
# |Virat Kohli                    |19   |
# |David Andrew Warner            |18   |
# |Mahendra Singh Dhoni           |18   |
# |Sunil Philip Narine            |17   |
# |Andre Dwayne Russell           |16   |
# |Ravindrasinh Anirudhsinh Jadeja|16   |
# |Yusuf Khan Pathan              |16   |
# +-------------------------------+-----+
# only showing top 10 rows

# %% [markdown]
# ### 5. Compare Home vs Away Team Performance

# %%
home_away=(
    ipl_data.groupBy("match_winner", "city")
    .count()
    .orderBy(col("count").desc())
)
home_away.show(truncate=False)
# Out:
# +---------------------------+----------+-----+
# |match_winner               |city      |count|
# +---------------------------+----------+-----+
# |Mumbai Indians             |Mumbai    |68   |
# |Kolkata Knight Riders      |Kolkata   |54   |
# |Chennai Super Kings        |Chennai   |51   |
# |Sunrisers Hyderabad        |Hyderabad |40   |
# |Rajasthan Royals           |Jaipur    |38   |
# |Delhi Capitals             |Delhi     |38   |
# |Punjab Kings               |Chandigarh|31   |
# |Royal Challengers Bangalore|Bangalore |28   |
# |Chennai Super Kings        |Mumbai    |18   |
# |Rajasthan Royals           |Mumbai    |17   |
# |Royal Challengers Bangalore|Bengaluru |17   |
# |Royal Challengers Bangalore|Mumbai    |13   |
# |Gujarat Titans             |Ahmedabad |13   |
# |Sunrisers Hyderabad        |Mumbai    |12   |
# |Punjab Kings               |Mumbai    |12   |
# |Delhi Capitals             |Mumbai    |11   |
# |Sunrisers Hyderabad        |Delhi     |11   |
# |Mumbai Indians             |Kolkata   |10   |
# |Punjab Kings               |NULL      |10   |
# |Rajasthan Royals           |Ahmedabad |10   |
# +---------------------------+----------+-----+
# only showing top 20 rows

# %% [markdown]
# # **36.Advanced Window Functions (Ranking + Running Totals + Lead/Lag)**

# %% [markdown]
# ### 1. Rank Teams by Wins (Dense Rank)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window
spark=SparkSession.builder.appName("IPL_Analytics").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)

ipl_data=matches_df.join(players_df, matches_df["player_of_match"] == players_df["player_id"], "left")\
                   .join(teams_df, matches_df["team1"] == teams_df["team_name"], "left")

win_count=ipl_data.groupBy("match_winner").agg(count("*").alias("wins")
)
WindowSpec=Window.orderBy(win_count.wins.desc())
ranked_teams=win_count.withColumn("rank", dense_rank().over(WindowSpec))
ranked_teams.show(truncate=False)
# Out:
# +---------------------------+----+----+
# |match_winner               |wins|rank|
# +---------------------------+----+----+
# |Mumbai Indians             |153 |1   |
# |Chennai Super Kings        |142 |2   |
# |Kolkata Knight Riders      |135 |3   |
# |Royal Challengers Bangalore|133 |4   |
# |Sunrisers Hyderabad        |125 |5   |
# |Punjab Kings               |123 |6   |
# |Delhi Capitals             |121 |7   |
# |Rajasthan Royals           |116 |8   |
# |Gujarat Titans             |37  |9   |
# |Lucknow Super Giants       |30  |10  |
# |Rising Pune Supergiant     |15  |11  |
# |Gujarat Lions              |13  |12  |
# |Pune Warriors              |12  |13  |
# |NULL                       |8   |14  |
# |Kochi Tuskers Kerala       |6   |15  |
# +---------------------------+----+----+

# %% [markdown]
# ### 2. Rolling Match Count per Team (Running Total)

# %%
window_team=Window.partitionBy("match_winner").orderBy("match_winner")
running_total= (
    ipl_data.withColumn("runnin_win_number",
                        row_number().over(window_team))
)
running_total.select("match_winner","match_date", "runnin_win_number").show(truncate=False)
# Out:
# +-------------------+----------+-----------------+
# |match_winner       |match_date|runnin_win_number|
# +-------------------+----------+-----------------+
# |NULL               |30-04-2019|1                |
# |NULL               |03-05-2023|2                |
# |NULL               |21-05-2011|3                |
# |NULL               |29-04-2015|4                |
# |NULL               |17-05-2015|5                |
# |NULL               |26-04-2025|6                |
# |NULL               |05-05-2025|7                |
# |NULL               |17-05-2025|8                |
# |Chennai Super Kings|07-04-2018|1                |
# |Chennai Super Kings|10-04-2018|2                |
# |Chennai Super Kings|20-04-2018|3                |
# |Chennai Super Kings|22-04-2018|4                |
# |Chennai Super Kings|25-04-2018|5                |
# |Chennai Super Kings|30-04-2018|6                |
# |Chennai Super Kings|05-05-2018|7                |
# |Chennai Super Kings|13-05-2018|8                |
# |Chennai Super Kings|20-05-2018|9                |
# |Chennai Super Kings|22-05-2018|10               |
# |Chennai Super Kings|27-05-2018|11               |
# |Chennai Super Kings|23-03-2019|12               |
# +-------------------+----------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### 3.Lag Analysis: Was Previous Match Won?

# %%
win_flag = (
    ipl_data.withColumn("is_win", (ipl_data.match_winner == ipl_data.team1).cast("int"))
          .withColumn("previous_game_win",
                      lag("is_win", 1).over(Window.partitionBy("team1").orderBy("match_date")))
)

win_flag.show(10, truncate=False)
# Out:
# +--------+---------+--------------+------------+----------+---------------------+------------+------+----------+-------------------+-----+------+---------+---------------------------------------------+-------------------+-------------------+---------------------+-------------+-------------------+-----------+--------------+---------------+------+-----+---------+-------------+--------------+----------------------+------------+-------------------------------+------------------------+----------------------------------------------------------------------------------------------------+-------+-------------------+---------------+---------------------------------------------------------------------+------+-----------------+
# |match_id|season_id|balls_per_over|city        |match_date|event_name           |match_number|gender|match_type|format             |overs|season|team_type|venue                                        |toss_winner        |team1              |team2                |toss_decision|match_winner       |win_by_runs|win_by_wickets|player_of_match|result|stage|player_id|player_name  |bat_style     |bowl_style            |field_pos   |player_full_name               |player_name2            |player_image                                                                                        |team_id|team_name          |team_name_short|image_url                                                            |is_win|previous_game_win|
# +--------+---------+--------------+------------+----------+---------------------+------------+------+----------+-------------------+-----+------+---------+---------------------------------------------+-------------------+-------------------+---------------------+-------------+-------------------+-----------+--------------+---------------+------+-----+---------+-------------+--------------+----------------------+------------+-------------------------------+------------------------+----------------------------------------------------------------------------------------------------+-------+-------------------+---------------+---------------------------------------------------------------------+------+-----------------+
# |501236  |2011     |6             |Chennai     |01-05-2011|Indian Premier League|39          |male  |T20       |2025-11-15 20:00:00|20   |2011  |club     |MA Chidambaram Stadium, Chepauk              |Chennai Super Kings|Chennai Super Kings|Sunrisers Hyderabad  |bat          |Chennai Super Kings|19         |NULL          |12234          |win   |NULL |12234    |JA Morkel    |Left hand Bat |Right arm Medium fast |            |Johannes Albertus Morkel       |Johannes Albertus       |NULL                                                                                                |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|1     |NULL             |
# |1178425 |2019     |6             |Chennai     |01-05-2019|Indian Premier League|50          |male  |T20       |2025-11-15 20:00:00|20   |2019  |club     |MA Chidambaram Stadium                       |Delhi Capitals     |Chennai Super Kings|Delhi Capitals       |field        |Chennai Super Kings|80         |NULL          |38             |win   |NULL |38       |MS Dhoni     |Right hand Bat|Right arm Medium      |Wicketkeeper|Mahendra Singh Dhoni           |Mahendra Singh          |NULL                                                                                                |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|1     |1                |
# |1254084 |2021     |6             |Delhi       |01-05-2021|Indian Premier League|27          |male  |T20       |2025-11-15 20:00:00|20   |2021  |club     |Arun Jaitley Stadium, Delhi                  |Mumbai Indians     |Chennai Super Kings|Mumbai Indians       |field        |Mumbai Indians     |NULL       |4             |29             |win   |NULL |29       |KA Pollard   |Right hand Bat|Right arm Medium      |            |Kieron Adrian Pollard          |Kieron Adrian           |NULL                                                                                                |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|0     |1                |
# |1304092 |2022     |6             |Pune        |01-05-2022|Indian Premier League|46          |male  |T20       |2025-11-15 20:00:00|20   |2022  |club     |Maharashtra Cricket Association Stadium, Pune|Sunrisers Hyderabad|Chennai Super Kings|Sunrisers Hyderabad  |field        |Chennai Super Kings|13         |NULL          |4119           |win   |NULL |4119     |RD Gaikwad   |Right hand Bat|Right arm Offbreak    |            |Ruturaj Dashrat Gaikwad        |Ruturaj Dashrat         |https://ipl-stats-sports-mechanic.s3.ap-south-1.amazonaws.com/ipl/playerimages/Ruturaj%20Gaikwad.png|129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|1     |0                |
# |1426287 |2024     |6             |Chennai     |01-05-2024|Indian Premier League|49          |male  |T20       |2025-11-15 20:00:00|20   |2024  |club     |MA Chidambaram Stadium, Chepauk, Chennai     |Punjab Kings       |Chennai Super Kings|Punjab Kings         |field        |Punjab Kings       |NULL       |7             |3495           |win   |NULL |3495     |Harpreet Brar|Left hand Bat |Slow Left arm Orthodox|            |Harpreet Brar                  |Harpreet Brar           |https://www.espncricinfo.com/cricketers/harpreet-brar-1168641                                       |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|0     |1                |
# |336040  |2008     |6             |Mumbai      |01-06-2008|Indian Premier League|NULL        |male  |T20       |2025-11-15 20:00:00|20   |2008  |club     |Dr DY Patil Sports Academy                   |Rajasthan Royals   |Chennai Super Kings|Rajasthan Royals     |field        |Rajasthan Royals   |NULL       |3             |60             |win   |NULL |60       |YK Pathan    |Right hand Bat|Right arm Offbreak    |            |Yusuf Khan Pathan              |Yusuf Khan              |NULL                                                                                                |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|0     |0                |
# |336001  |2008     |6             |Chennai     |02-05-2008|Indian Premier League|20          |male  |T20       |2025-11-15 20:00:00|20   |2008  |club     |MA Chidambaram Stadium, Chepauk              |Chennai Super Kings|Chennai Super Kings|Delhi Capitals       |bat          |Delhi Capitals     |NULL       |8             |11975          |win   |NULL |11975    |V Sehwag     |Right hand Bat|Right arm Offbreak    |            |Virender Sehwag                |Virender Sehwag         |NULL                                                                                                |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|0     |0                |
# |392206  |2009     |6             |Johannesburg|02-05-2009|Indian Premier League|26          |male  |T20       |2025-11-15 20:00:00|20   |2009  |club     |New Wanderers Stadium                        |Delhi Capitals     |Chennai Super Kings|Delhi Capitals       |field        |Chennai Super Kings|18         |NULL          |53             |win   |NULL |53       |SB Jakati    |Left hand Bat |Slow Left arm Orthodox|            |Shadab Bashir Jakati           |Shadab Bashir           |NULL                                                                                                |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|1     |0                |
# |598041  |2013     |6             |Chennai     |02-05-2013|Indian Premier League|45          |male  |T20       |2025-11-15 20:00:00|20   |2013  |club     |MA Chidambaram Stadium, Chepauk              |Chennai Super Kings|Chennai Super Kings|Punjab Kings         |bat          |Chennai Super Kings|15         |NULL          |47             |win   |NULL |47       |SK Raina     |Left hand Bat |Right arm Offbreak    |            |Suresh Kumar Raina             |Suresh Kumar            |NULL                                                                                                |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|1     |1                |
# |733971  |2014     |6             |Ranchi      |02-05-2014|Indian Premier League|21          |male  |T20       |2025-11-15 20:00:00|20   |2014  |club     |JSCA International Stadium Complex           |Chennai Super Kings|Chennai Super Kings|Kolkata Knight Riders|bat          |Chennai Super Kings|34         |NULL          |348            |win   |NULL |348      |RA Jadeja    |Left hand Bat |Slow Left arm Orthodox|            |Ravindrasinh Anirudhsinh Jadeja|Ravindrasinh Anirudhsinh|NULL                                                                                                |129    |Chennai Super Kings|CSK            |https://documents.iplt20.com/ipl/CSK/logos/Logooutline/CSKoutline.png|1     |1                |
# +--------+---------+--------------+------------+----------+---------------------+------------+------+----------+-------------------+-----+------+---------+---------------------------------------------+-------------------+-------------------+---------------------+-------------+-------------------+-----------+--------------+---------------+------+-----+---------+-------------+--------------+----------------------+------------+-------------------------------+------------------------+----------------------------------------------------------------------------------------------------+-------+-------------------+---------------+---------------------------------------------------------------------+------+-----------------+
# only showing top 10 rows

# %% [markdown]
# ### 4. Lead Function: Who Will They Face Next?

# %%
next_opponent=(
    ipl_data.withColumn("Next_team",
                        lead("team2", 1).over(Window.partitionBy("team1").orderBy("match_date"))
))
next_opponent.select("team1", "team2", "Next_team").show(truncate=False)
# Out:
# +-------------------+---------------------------+---------------------------+
# |team1              |team2                      |Next_team                  |
# +-------------------+---------------------------+---------------------------+
# |Chennai Super Kings|Sunrisers Hyderabad        |Delhi Capitals             |
# |Chennai Super Kings|Delhi Capitals             |Mumbai Indians             |
# |Chennai Super Kings|Mumbai Indians             |Sunrisers Hyderabad        |
# |Chennai Super Kings|Sunrisers Hyderabad        |Punjab Kings               |
# |Chennai Super Kings|Punjab Kings               |Rajasthan Royals           |
# |Chennai Super Kings|Rajasthan Royals           |Delhi Capitals             |
# |Chennai Super Kings|Delhi Capitals             |Delhi Capitals             |
# |Chennai Super Kings|Delhi Capitals             |Punjab Kings               |
# |Chennai Super Kings|Punjab Kings               |Kolkata Knight Riders      |
# |Chennai Super Kings|Kolkata Knight Riders      |Rajasthan Royals           |
# |Chennai Super Kings|Rajasthan Royals           |Rajasthan Royals           |
# |Chennai Super Kings|Rajasthan Royals           |Lucknow Super Giants       |
# |Chennai Super Kings|Lucknow Super Giants       |Kolkata Knight Riders      |
# |Chennai Super Kings|Kolkata Knight Riders      |Mumbai Indians             |
# |Chennai Super Kings|Mumbai Indians             |Sunrisers Hyderabad        |
# |Chennai Super Kings|Sunrisers Hyderabad        |Rajasthan Royals           |
# |Chennai Super Kings|Rajasthan Royals           |Sunrisers Hyderabad        |
# |Chennai Super Kings|Sunrisers Hyderabad        |Royal Challengers Bangalore|
# |Chennai Super Kings|Royal Challengers Bangalore|Delhi Capitals             |
# |Chennai Super Kings|Delhi Capitals             |Sunrisers Hyderabad        |
# +-------------------+---------------------------+---------------------------+
# only showing top 20 rows

# %% [markdown]
# ### 5. Most Consistent Teams (Rolling Win Rate)

# %%
win_rate_spec = Window.partitionBy("match_winner").orderBy("match_date").rowsBetween(Window.unboundedPreceding, 0)

rolling_rate = (
    ipl_data.withColumn("win_flag", (col("match_winner").isNotNull()).cast("int"))
          .withColumn("rolling_win_rate",
                      avg("win_flag").over(win_rate_spec))
)

rolling_rate.select("match_winner", "match_date", "rolling_win_rate").show()
# Out:
# +-------------------+----------+----------------+
# |       match_winner|match_date|rolling_win_rate|
# +-------------------+----------+----------------+
# |               NULL|03-05-2023|             0.0|
# |               NULL|05-05-2025|             0.0|
# |               NULL|17-05-2015|             0.0|
# |               NULL|17-05-2025|             0.0|
# |               NULL|21-05-2011|             0.0|
# |               NULL|26-04-2025|             0.0|
# |               NULL|29-04-2015|             0.0|
# |               NULL|30-04-2019|             0.0|
# |Chennai Super Kings|01-05-2011|             1.0|
# |Chennai Super Kings|01-05-2019|             1.0|
# |Chennai Super Kings|01-05-2022|             1.0|
# |Chennai Super Kings|01-11-2020|             1.0|
# |Chennai Super Kings|02-05-2009|             1.0|
# |Chennai Super Kings|02-05-2013|             1.0|
# |Chennai Super Kings|02-05-2014|             1.0|
# |Chennai Super Kings|03-04-2010|             1.0|
# |Chennai Super Kings|03-04-2023|             1.0|
# |Chennai Super Kings|04-05-2009|             1.0|
# |Chennai Super Kings|04-05-2011|             1.0|
# |Chennai Super Kings|04-05-2012|             1.0|
# +-------------------+----------+----------------+
# only showing top 20 rows

# %% [markdown]
# # **37.PySpark Joins: Advanced + Real-World Optimizations**

# %% [markdown]
# ### 1. Broadcast Join (Small lookup table: teams_data)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window
spark=SparkSession.builder.appName("IPL_Analytics").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)
matches = matches_df.withColumn("team1_k", upper(trim(col("team1")))) \
                 .withColumn("team2_k", upper(trim(col("team2"))))

teams = teams_df.withColumn("team_k", upper(trim(col("team_name"))))

matches_broadcast = matches.join(
    broadcast(teams),
    matches.team1_k == teams.team_k,
    "left"
).withColumnRenamed("team_name_short", "team1_short")

matches_broadcast.show(5)
# Out:
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+--------------------+--------------------+-------+--------------------+-----------+--------------------+--------------------+
# |match_id|season_id|balls_per_over|     city|match_date|          event_name|match_number|gender|match_type|             format|overs|season|team_type|               venue|         toss_winner|               team1|               team2|toss_decision|        match_winner|win_by_runs|win_by_wickets|player_of_match|result|stage|             team1_k|             team2_k|team_id|           team_name|team1_short|           image_url|              team_k|
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+--------------------+--------------------+-------+--------------------+-----------+--------------------+--------------------+
# |  335982|     2008|             6|Bangalore|18-04-2008|Indian Premier Le...|           1|  male|       T20|2025-11-16 20:00:00|   20|  2008|     club|M Chinnaswamy Sta...|Royal Challengers...|Royal Challengers...|Kolkata Knight Ri...|        field|Kolkata Knight Ri...|        140|          NULL|             46|   win| NULL|ROYAL CHALLENGERS...|KOLKATA KNIGHT RI...|      1|Royal Challengers...|        RCB|https://documents...|ROYAL CHALLENGERS...|
# | 1082591|     2017|             6|Hyderabad|05-04-2017|Indian Premier Le...|           1|  male|       T20|2025-11-16 20:00:00|   20|  2017|     club|Rajiv Gandhi Inte...|Royal Challengers...| Sunrisers Hyderabad|Royal Challengers...|        field| Sunrisers Hyderabad|         35|          NULL|             15|   win| NULL| SUNRISERS HYDERABAD|ROYAL CHALLENGERS...|      2| Sunrisers Hyderabad|        SRH|https://documents...| SUNRISERS HYDERABAD|
# | 1082592|     2017|             6|     Pune|06-04-2017|Indian Premier Le...|           2|  male|       T20|2025-11-16 20:00:00|   20|  2017|     club|Maharashtra Crick...|Rising Pune Super...|Rising Pune Super...|      Mumbai Indians|        field|Rising Pune Super...|       NULL|             7|             36|   win| NULL|RISING PUNE SUPER...|      MUMBAI INDIANS|      4|Rising Pune Super...|        RPS|https://ipl-stats...|RISING PUNE SUPER...|
# | 1082593|     2017|             6|   Rajkot|07-04-2017|Indian Premier Le...|           3|  male|       T20|2025-11-16 20:00:00|   20|  2017|     club|Saurashtra Cricke...|Kolkata Knight Ri...|       Gujarat Lions|Kolkata Knight Ri...|        field|Kolkata Knight Ri...|       NULL|            10|             57|   win| NULL|       GUJARAT LIONS|KOLKATA KNIGHT RI...|      5|       Gujarat Lions|         GL|https://ipl-stats...|       GUJARAT LIONS|
# | 1082594|     2017|             6|   Indore|08-04-2017|Indian Premier Le...|           4|  male|       T20|2025-11-16 20:00:00|   20|  2017|     club|Holkar Cricket St...|        Punjab Kings|        Punjab Kings|Rising Pune Super...|        field|        Punjab Kings|       NULL|             6|             71|   win| NULL|        PUNJAB KINGS|RISING PUNE SUPER...|    494|        Punjab Kings|         PK|https://documents...|        PUNJAB KINGS|
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+--------------------+--------------------+-------+--------------------+-----------+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ### 2.Left Anti Join (Find Missing Players)

# %%
players = players_df.withColumn("player_k", upper(trim(col("player_full_name"))))
matches = matches_df.withColumn("pom_k", upper(trim(col("player_of_match"))))

missing_pom = matches.join(
    players,
    matches.pom_k == players.player_k,
    "left_anti"
)

missing_pom.select("match_date", "team1", "team2", "player_of_match").show(10, truncate=False)
# Out:
# +----------+---------------------------+---------------------------+---------------+
# |match_date|team1                      |team2                      |player_of_match|
# +----------+---------------------------+---------------------------+---------------+
# |18-04-2008|Royal Challengers Bangalore|Kolkata Knight Riders      |46             |
# |05-04-2017|Sunrisers Hyderabad        |Royal Challengers Bangalore|15             |
# |06-04-2017|Rising Pune Supergiant     |Mumbai Indians             |36             |
# |07-04-2017|Gujarat Lions              |Kolkata Knight Riders      |57             |
# |08-04-2017|Punjab Kings               |Rising Pune Supergiant     |71             |
# |08-04-2017|Royal Challengers Bangalore|Delhi Capitals             |4              |
# |09-04-2017|Sunrisers Hyderabad        |Gujarat Lions              |22             |
# |09-04-2017|Mumbai Indians             |Kolkata Knight Riders      |26             |
# |10-04-2017|Punjab Kings               |Royal Challengers Bangalore|70             |
# |11-04-2017|Rising Pune Supergiant     |Delhi Capitals             |180            |
# +----------+---------------------------+---------------------------+---------------+
# only showing top 10 rows

# %% [markdown]
# ### 3.Semi Join (Only players who ever got POM)

# %%
players_with_pom = players.join(
    matches,
    players.player_k == matches.pom_k,
    "left_semi"
)

players_with_pom.show(10)
# Out:
# +---------+-----------+---------+----------+---------+----------------+------------+------------+--------+
# |player_id|player_name|bat_style|bowl_style|field_pos|player_full_name|player_name2|player_image|player_k|
# +---------+-----------+---------+----------+---------+----------------+------------+------------+--------+
# +---------+-----------+---------+----------+---------+----------------+------------+------------+--------+

# %% [markdown]
# ### 4.Multi-Condition Join (team + season)

# %%
season_team_join = matches.join(
    teams,
    (upper(trim(matches.team1)) == upper(trim(teams.team_name))),
    "left"
)

season_team_join.show(5)
# Out:
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+-----+-------+--------------------+---------------+--------------------+--------------------+
# |match_id|season_id|balls_per_over|     city|match_date|          event_name|match_number|gender|match_type|             format|overs|season|team_type|               venue|         toss_winner|               team1|               team2|toss_decision|        match_winner|win_by_runs|win_by_wickets|player_of_match|result|stage|pom_k|team_id|           team_name|team_name_short|           image_url|              team_k|
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+-----+-------+--------------------+---------------+--------------------+--------------------+
# |  335982|     2008|             6|Bangalore|18-04-2008|Indian Premier Le...|           1|  male|       T20|2025-11-16 20:00:00|   20|  2008|     club|M Chinnaswamy Sta...|Royal Challengers...|Royal Challengers...|Kolkata Knight Ri...|        field|Kolkata Knight Ri...|        140|          NULL|             46|   win| NULL|   46|      1|Royal Challengers...|            RCB|https://documents...|ROYAL CHALLENGERS...|
# | 1082591|     2017|             6|Hyderabad|05-04-2017|Indian Premier Le...|           1|  male|       T20|2025-11-16 20:00:00|   20|  2017|     club|Rajiv Gandhi Inte...|Royal Challengers...| Sunrisers Hyderabad|Royal Challengers...|        field| Sunrisers Hyderabad|         35|          NULL|             15|   win| NULL|   15|      2| Sunrisers Hyderabad|            SRH|https://documents...| SUNRISERS HYDERABAD|
# | 1082592|     2017|             6|     Pune|06-04-2017|Indian Premier Le...|           2|  male|       T20|2025-11-16 20:00:00|   20|  2017|     club|Maharashtra Crick...|Rising Pune Super...|Rising Pune Super...|      Mumbai Indians|        field|Rising Pune Super...|       NULL|             7|             36|   win| NULL|   36|      4|Rising Pune Super...|            RPS|https://ipl-stats...|RISING PUNE SUPER...|
# | 1082593|     2017|             6|   Rajkot|07-04-2017|Indian Premier Le...|           3|  male|       T20|2025-11-16 20:00:00|   20|  2017|     club|Saurashtra Cricke...|Kolkata Knight Ri...|       Gujarat Lions|Kolkata Knight Ri...|        field|Kolkata Knight Ri...|       NULL|            10|             57|   win| NULL|   57|      5|       Gujarat Lions|             GL|https://ipl-stats...|       GUJARAT LIONS|
# | 1082594|     2017|             6|   Indore|08-04-2017|Indian Premier Le...|           4|  male|       T20|2025-11-16 20:00:00|   20|  2017|     club|Holkar Cricket St...|        Punjab Kings|        Punjab Kings|Rising Pune Super...|        field|        Punjab Kings|       NULL|             6|             71|   win| NULL|   71|    494|        Punjab Kings|             PK|https://documents...|        PUNJAB KINGS|
# +--------+---------+--------------+---------+----------+--------------------+------------+------+----------+-------------------+-----+------+---------+--------------------+--------------------+--------------------+--------------------+-------------+--------------------+-----------+--------------+---------------+------+-----+-----+-------+--------------------+---------------+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ### 5.Aggregation after join (Top winning teams)

# %%
from pyspark.sql import functions as F

top_teams = matches.groupBy("match_winner") \
                   .agg(F.count("*").alias("wins")) \
                   .orderBy(F.desc("wins"))

top_teams.show(10,truncate=False)
# Out:
# +---------------------------+----+
# |match_winner               |wins|
# +---------------------------+----+
# |Mumbai Indians             |153 |
# |Chennai Super Kings        |142 |
# |Kolkata Knight Riders      |135 |
# |Royal Challengers Bangalore|133 |
# |Sunrisers Hyderabad        |125 |
# |Punjab Kings               |123 |
# |Delhi Capitals             |121 |
# |Rajasthan Royals           |116 |
# |Gujarat Titans             |37  |
# |Lucknow Super Giants       |30  |
# +---------------------------+----+
# only showing top 10 rows

# %% [markdown]
# # **38.Real-Time Analysis Basics in PySpark (Structured Streaming)**

# %% [markdown]
# ### 1.Create a Streaming DataFrame (Socket Source)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Day38_Streaming").getOrCreate()

stream_df = spark.readStream \
    .format("socket") \
    .option("host", "localhost") \
    .option("port", 9999) \
    .load()

stream_df.printSchema()
# Out:
# root
#  |-- value: string (nullable = true)

# %% [markdown]
# ###Real-Time Word Count (classic streaming test)

# %%
from pyspark.sql.functions import explode, split

words = stream_df.select(
    explode(split(stream_df.value, " ")).alias("word")
)

word_count = words.groupBy("word").count()

# %%
word_count.writeStream \
    .format("console") \
    .outputMode("complete") \
    .start() \
    .awaitTermination()

# %% [markdown]
# ###Real-Time Aggregation with Sliding Windows

# %%
from pyspark.sql.functions import window, current_timestamp

windowed_counts = stream_df \
    .withColumn("timestamp", current_timestamp()) \
    .withWatermark("timestamp", "1 minute") \
    .groupBy(\
        window("timestamp", "30 seconds", "10 seconds")\
    ) \
    .count()

# %% [markdown]
# ###Reading Real-Time Data from Files (Auto-Refresh Directory)

# %%
file_stream = spark.readStream \
    .format("csv") \
    .option("header", True) \
    .schema(schema) \
    .load("/content/input_folder/")

# %% [markdown]
# ### Writing Streaming Output to Delta / Parquet

# %%
query = windowed_counts.writeStream \
    .format("parquet") \
    .option("path", "/content/output/") \
    .option("checkpointLocation", "/content/checkpoints/") \
    .outputMode("append") \
    .start()

# %% [markdown]
# # **39.Real-Time Analysis Basics with IPL Dataset (PySpark)**

# %% [markdown]
# ###Real-Time Ingestion of IPL Ball-by-Ball Records

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
spark=SparkSession.builder.appName("IPL_Analytics").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)
ball_by_ball_df=spark.read.csv("/content/ball_by_ball_data.csv", header=True, inferSchema=True)
ipl_data=matches_df.join(players_df, matches_df["player_of_match"] == players_df["player_id"], "left")\
                   .join(teams_df, matches_df["team1"] == teams_df["team_name"], "left")\
                   .join(ball_by_ball_df, matches_df["match_id"]== ball_by_ball_df["match_id"], "left")
stream_df= spark.readStream\
        .schema(ball_by_ball_df.schema)\
        .csv("/content/ball_by_ball_data.csv")
stream_df.printSchema()
# Out:
# root
#  |-- season_id: integer (nullable = true)
#  |-- match_id: integer (nullable = true)
#  |-- batter: string (nullable = true)
#  |-- bowler: string (nullable = true)
#  |-- non_striker: string (nullable = true)
#  |-- team_batting: string (nullable = true)
#  |-- team_bowling: string (nullable = true)
#  |-- over_number: integer (nullable = true)
#  |-- ball_number: integer (nullable = true)
#  |-- batter_runs: integer (nullable = true)
#  |-- extras: integer (nullable = true)
#  |-- total_runs: integer (nullable = true)
#  |-- batsman_type: string (nullable = true)
#  |-- bowler_type: string (nullable = true)
#  |-- player_out: string (nullable = true)
#  |-- fielders_involved: string (nullable = true)
#  |-- is_wicket: string (nullable = true)
#  |-- is_wide_ball: string (nullable = true)
#  |-- is_no_ball: boolean (nullable = true)
#  |-- is_leg_bye: boolean (nullable = true)
#  |-- is_bye: boolean (nullable = true)
#  |-- is_penalty: boolean (nullable = true)
#  |-- wide_ball_runs: string (nullable = true)
#  |-- no_ball_runs: string (nullable = true)
#  |-- leg_bye_runs: integer (nullable = true)
#  |-- bye_runs: integer (nullable = true)
#  |-- penalty_runs: integer (nullable = true)
#  |-- wicket_kind: string (nullable = true)
#  |-- is_super_over: string (nullable = true)
#  |-- innings: string (nullable = true)

# %% [markdown]
# ### Real-Time Run Rate Monitoring per Over

# %%
real_time_df=stream_df.groupBy("match_id","innings","over_number")\
  .agg(sum("total_runs").alias("runs_this_over"))

# %% [markdown]
# ###Real-Time Wicket Alert

# %%
Wicket_alert = stream_df.filter(col("player_out").isNotNull())

# %% [markdown]
# ### Real-Time Batsman performance Tracker

# %%
batsman_Live=stream_df.groupBy("batter") \
      .agg(
          sum("total_runs").alias("runs"),
          count("ball_number").alias("balls")
      )

# %% [markdown]
# ###Real-Time Match Momentum Score (Custom KPI)

# %%
momentum_df = stream_df.groupBy("match_id") \
    .agg(
        sum("total_runs").alias("runs"),
        count("player_out").alias("wkts"),
        max("over_number").alias("overs")
    )

# To see the real-time output, you need to start a streaming query

# %% [markdown]
# # **40.Advanced IPL Data Transformations in PySpark**

# %% [markdown]
# ### 1 - Create a clean player Performance Table

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
spark=SparkSession.builder.appName("IPL_Performance").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)
ball_by_ball_df=spark.read.csv("/content/ball_by_ball_data.csv", header=True, inferSchema=True)
ipl_data=matches_df.join(players_df, matches_df["player_of_match"] == players_df["player_id"], "left")\
                   .join(teams_df, matches_df["team1"] == teams_df["team_name"], "left")\
                   .join(ball_by_ball_df, matches_df["match_id"]== ball_by_ball_df["match_id"], "left")
player_stats= ball_by_ball_df.groupBy("batter").agg(
    sum("batter_runs").alias("Total_runs"),
    count("ball_number").alias("Faced_balls"),
    round((sum("batter_runs") / count("ball_number"))*100,2).alias("Strike_rate")
)
player_stats.show()
# Out:
# +---------------+----------+-----------+-----------+
# |         batter|Total_runs|Faced_balls|Strike_rate|
# +---------------+----------+-----------+-----------+
# |  Kuldeep Yadav|       201|        240|      83.75|
# |     S Anirudha|       136|        121|      112.4|
# |     TM Dilshan|      1153|       1047|     110.12|
# |     KA Pollard|      3437|       2447|     140.46|
# |   M Theekshana|        17|         34|       50.0|
# | M Muralitharan|        20|         30|      66.67|
# |  LA Carseldine|        81|         71|     114.08|
# |    SS Cottrell|         0|          2|        0.0|
# |      CA Ingram|       205|        183|     112.02|
# | R Sanjay Yadav|         0|          2|        0.0|
# |       DR Smith|      2385|       1803|     132.28|
# |     A Flintoff|        62|         57|     108.77|
# |       M Manhas|       514|        486|     105.76|
# |      GR Napier|        15|         16|      93.75|
# |       AR Patel|      1916|       1489|     128.68|
# |       SA Yadav|      4311|       2961|     145.59|
# |          B Lee|       124|        102|     121.57|
# |       A Mukund|        19|         23|      82.61|
# |     D du Preez|        10|         13|      76.92|
# |NM Coulter-Nile|        82|         75|     109.33|
# +---------------+----------+-----------+-----------+
# only showing top 20 rows

# %% [markdown]
# ### 2-Team-wise Boundary (4s and 6s) Analysis

# %%
boundaries = ipl_data.groupBy("team_batting").agg(
    sum(when(ipl_data.batter_runs ==4,1).otherwise(0)).alias("Fours"),
    sum(when(ipl_data.batter_runs ==6,1).otherwise(0)).alias("Sixes")
)
boundaries.show(truncate=True)
# Out:
# +--------------------+-----+-----+
# |        team_batting|Fours|Sixes|
# +--------------------+-----+-----+
# | Sunrisers Hyderabad| 3581| 1562|
# |Lucknow Super Giants|  795|  484|
# | Chennai Super Kings| 3395| 1611|
# |      Gujarat Titans|  947|  395|
# |                NULL|    0|    0|
# |Rising Pune Super...|  368|  157|
# |Kochi Tuskers Kerala|  170|   53|
# |    Rajasthan Royals| 3302| 1383|
# |       Gujarat Lions|  460|  155|
# |Royal Challengers...| 3617| 1778|
# |Kolkata Knight Ri...| 3634| 1596|
# |        Punjab Kings| 3681| 1688|
# |       Pune Warriors|  525|  196|
# |      Delhi Capitals| 3729| 1461|
# |      Mumbai Indians| 3897| 1828|
# +--------------------+-----+-----+

# %% [markdown]
# ### 3-Most Economical Bowlers (Full IPL Dataset)

# %%
eco_bowler = ipl_data.groupBy("bowler").agg(
    sum("total_runs").alias("Runs_Given"),
    count("ball_number").alias("Balls_Bowled")
).withColumn(
    "Economy", round(col("Runs_Given") / (col("Balls_Bowled")/6), 2)
)

eco_bowler.orderBy("Economy").show(20)
# Out:
# +---------------+----------+------------+-------+
# |         bowler|Runs_Given|Balls_Bowled|Economy|
# +---------------+----------+------------+-------+
# |           NULL|      NULL|           0|   NULL|
# |   AC Gilchrist|         0|           1|    0.0|
# |     R Ravindra|         7|          12|    3.5|
# |       NB Singh|        18|          25|   4.32|
# |    Sachin Baby|         8|          10|    4.8|
# |      AM Rahane|         5|           6|    5.0|
# |  LA Carseldine|         6|           7|   5.14|
# |      SS Mundhe|         6|           7|   5.14|
# |    DJ Thornely|        40|          44|   5.45|
# |       M Manhas|        42|          42|    6.0|
# |      DA Warner|         2|           2|    6.0|
# |       MW Short|        25|          25|    6.0|
# |  Sohail Tanvir|       275|         265|   6.23|
# |     A Chandila|       245|         234|   6.28|
# |     FH Edwards|       160|         150|    6.4|
# |SMSM Senanayake|       211|         195|   6.49|
# |    JW Hastings|        66|          61|   6.49|
# |     KA Maharaj|        39|          36|    6.5|
# |     PH Solanki|        39|          36|    6.5|
# |      MJ Clarke|        72|          66|   6.55|
# +---------------+----------+------------+-------+
# only showing top 20 rows

# %% [markdown]
# ### 4.Match Stage Classification (Powerplay / Middle / Death)

# %%
from pyspark.sql.functions import when

stage_df = ipl_data.withColumn(
    "Stage",
    when(col("over_number") <= 6, "Powerplay")
    .when(col("over_number") <= 15, "Middle Overs")
    .otherwise("Death Overs")
)

stage_df.groupBy("Stage").agg(sum("total_runs").alias("Runs")).show()
# Out:
# +------------+------+
# |       Stage|  Runs|
# +------------+------+
# | Death Overs| 80588|
# |   Powerplay|127556|
# |Middle Overs|166017|
# +------------+------+

# %% [markdown]
# ### 5.Create a Player vs Team Performance Matrix

# %%
player_team_matrix = ipl_data.groupBy("batter", "team_bowling").agg(
    sum("batter_runs").alias("Runs_Scored")
)

player_team_matrix.show(20)
# Out:
# +----------------+--------------------+-----------+
# |          batter|        team_bowling|Runs_Scored|
# +----------------+--------------------+-----------+
# |       SP Narine|    Rajasthan Royals|        268|
# |         M Vohra|        Punjab Kings|         12|
# |      D Padikkal|Royal Challengers...|        115|
# |    F du Plessis| Chennai Super Kings|        197|
# |     Mohsin Khan|        Punjab Kings|         15|
# |DPMD Jayawardene|Royal Challengers...|        140|
# |    DB Ravi Teja|Kolkata Knight Ri...|         64|
# |      SD Chitnis|        Punjab Kings|         15|
# |       AA Chavan|      Mumbai Indians|          4|
# |     RJ Peterson|       Pune Warriors|         13|
# |       CM Gautam| Chennai Super Kings|         20|
# |         A Zampa|      Delhi Capitals|          5|
# |   Kuldeep Yadav|Royal Challengers...|         39|
# |       AT Rayudu|    Rajasthan Royals|        377|
# |       DR Shorey|Royal Challengers...|          8|
# |         B Kumar| Chennai Super Kings|         39|
# |         AD Nath|      Delhi Capitals|         19|
# |       DA Miller|Royal Challengers...|        386|
# |     YBK Jaiswal|      Mumbai Indians|        296|
# | M Shahrukh Khan|Royal Challengers...|        142|
# +----------------+--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# # **41.Window Functions in PySpark (IPL Dataset)**

# %% [markdown]
# ### Import libraries and Load data

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window
spark=SparkSession.builder.appName("IPL_Performance").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)
ball_by_ball_df=spark.read.csv("/content/ball_by_ball_data.csv", header=True, inferSchema=True)
ipl_data=matches_df.join(players_df, matches_df["player_of_match"] == players_df["player_id"], "left")\
                   .join(teams_df, matches_df["team1"] == teams_df["team_name"], "left")\
                   .join(ball_by_ball_df.withColumnRenamed("match_id", "ball_by_ball_match_id"), matches_df["match_id"]== col("ball_by_ball_match_id"), "left")

# %% [markdown]
# ### 1. Ranking Teams by Wins(Dense_Rank)

# %%
Wins = (ipl_data.groupBy("season","match_winner")
                .agg(count("*").alias("Total_wins")))

w = Window.partitionBy("season").orderBy(col("Total_wins").desc())

result = Wins.withColumn("rank", dense_rank().over(w))
result.show()
# Out:
# +------+--------------------+----------+----+
# |season|        match_winner|Total_wins|rank|
# +------+--------------------+----------+----+
# |  2008|    Rajasthan Royals|      3094|   1|
# |  2008|        Punjab Kings|      2303|   2|
# |  2008| Chennai Super Kings|      2127|   3|
# |  2008|      Delhi Capitals|      1641|   4|
# |  2008|      Mumbai Indians|      1509|   5|
# |  2008|Kolkata Knight Ri...|      1400|   6|
# |  2008|Royal Challengers...|       977|   7|
# |  2008| Sunrisers Hyderabad|       438|   8|
# |  2009|      Delhi Capitals|      2305|   1|
# |  2009|Royal Challengers...|      2166|   2|
# |  2009| Sunrisers Hyderabad|      2164|   3|
# |  2009| Chennai Super Kings|      1869|   4|
# |  2009|        Punjab Kings|      1744|   5|
# |  2009|    Rajasthan Royals|      1474|   6|
# |  2009|      Mumbai Indians|      1205|   7|
# |  2009|Kolkata Knight Ri...|       679|   8|
# |  2010|      Mumbai Indians|      2704|   1|
# |  2010| Chennai Super Kings|      2181|   2|
# |  2010| Sunrisers Hyderabad|      1974|   3|
# |  2010|Royal Challengers...|      1821|   4|
# +------+--------------------+----------+----+
# only showing top 20 rows

# %% [markdown]
# ### 2.Player of Match Count Ranking

# %%
player_of_Match = (ipl_data.groupBy("player_of_Match")
                            .agg(count("*").alias("Player_of_Match_Count")))

w = Window.orderBy(col("Player_of_Match_Count").desc())

player_of_Match = player_of_Match.withColumn("rank", dense_rank().over(w))
player_of_Match.show()
# Out:
# +---------------+---------------------+----+
# |player_of_Match|Player_of_Match_Count|rank|
# +---------------+---------------------+----+
# |            245|                 6170|   1|
# |              1|                 5186|   2|
# |             25|                 5134|   3|
# |             38|                 4384|   4|
# |             12|                 4329|   5|
# |            332|                 4302|   6|
# |             65|                 4018|   7|
# |           1437|                 3905|   8|
# |            348|                 3864|   9|
# |              5|                 3807|  10|
# |             60|                 3735|  11|
# |           1409|                 3587|  12|
# |             29|                 3468|  13|
# |             24|                 3429|  14|
# |             47|                 3400|  15|
# |             34|                 3168|  16|
# |             56|                 3107|  17|
# |          11943|                 2905|  18|
# |           1580|                 2904|  19|
# |             13|                 2870|  20|
# +---------------+---------------------+----+
# only showing top 20 rows

# %% [markdown]
# ### 3. Running Total matches Each Season

# %%
w = Window.partitionBy("season").orderBy("match_id") \
          .rowsBetween(Window.unboundedPreceding, Window.currentRow)

ipl_running = ipl_data.withColumn("match_running_total", count("*").over(w))
ipl_running.select("season", "match_id", "match_running_total").show()
# Out:
# +------+--------+-------------------+
# |season|match_id|match_running_total|
# +------+--------+-------------------+
# |  2008|  335982|                  1|
# |  2008|  335982|                  2|
# |  2008|  335982|                  3|
# |  2008|  335982|                  4|
# |  2008|  335982|                  5|
# |  2008|  335982|                  6|
# |  2008|  335982|                  7|
# |  2008|  335982|                  8|
# |  2008|  335982|                  9|
# |  2008|  335982|                 10|
# |  2008|  335982|                 11|
# |  2008|  335982|                 12|
# |  2008|  335982|                 13|
# |  2008|  335982|                 14|
# |  2008|  335982|                 15|
# |  2008|  335982|                 16|
# |  2008|  335982|                 17|
# |  2008|  335982|                 18|
# |  2008|  335982|                 19|
# |  2008|  335982|                 20|
# +------+--------+-------------------+
# only showing top 20 rows

# %% [markdown]
# ### 4. Team Winning Percentage

# %%
wins = ipl_data.groupBy("season", "match_winner").agg(count("*").alias("win_count"))

w = Window.partitionBy("season")

result = wins.withColumn(
    "season_total_matches",
    sum("win_count").over(w)
).withColumn(
    "win_percentage",
    round(col("win_count") / col("season_total_matches") * 100, 2)
)

result.show()
# Out:
# +------+--------------------+---------+--------------------+--------------+
# |season|        match_winner|win_count|season_total_matches|win_percentage|
# +------+--------------------+---------+--------------------+--------------+
# |  2008|Royal Challengers...|      977|               13489|          7.24|
# |  2008|    Rajasthan Royals|     3094|               13489|         22.94|
# |  2008| Sunrisers Hyderabad|      438|               13489|          3.25|
# |  2008| Chennai Super Kings|     2127|               13489|         15.77|
# |  2008|      Mumbai Indians|     1509|               13489|         11.19|
# |  2008|        Punjab Kings|     2303|               13489|         17.07|
# |  2008|      Delhi Capitals|     1641|               13489|         12.17|
# |  2008|Kolkata Knight Ri...|     1400|               13489|         10.38|
# |  2009|        Punjab Kings|     1744|               13606|         12.82|
# |  2009|      Mumbai Indians|     1205|               13606|          8.86|
# |  2009|    Rajasthan Royals|     1474|               13606|         10.83|
# |  2009|Kolkata Knight Ri...|      679|               13606|          4.99|
# |  2009| Chennai Super Kings|     1869|               13606|         13.74|
# |  2009| Sunrisers Hyderabad|     2164|               13606|          15.9|
# |  2009|Royal Challengers...|     2166|               13606|         15.92|
# |  2009|      Delhi Capitals|     2305|               13606|         16.94|
# |  2010|Kolkata Knight Ri...|     1711|               14498|          11.8|
# |  2010|    Rajasthan Royals|     1431|               14498|          9.87|
# |  2010|      Mumbai Indians|     2704|               14498|         18.65|
# |  2010| Sunrisers Hyderabad|     1974|               14498|         13.62|
# +------+--------------------+---------+--------------------+--------------+
# only showing top 20 rows

# %% [markdown]
# ### 5.Lead & Lag: Match Result Trend

# %%
team_w=Window.partitionBy("match_winner").orderBy("match_date")

trend=(
    ipl_data.withColumn("prev_match", lag("match_winner").over(team_w))
    .withColumn("next_match", lead("match_winner").over(team_w))
)
trend.select("match_winner", "prev_match", "next_match").show()
# Out:
# +------------+----------+----------+
# |match_winner|prev_match|next_match|
# +------------+----------+----------+
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# |        NULL|      NULL|      NULL|
# +------------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# # **43. PySpark UDFs (User Defined Functions) With IPLDataset**

# %% [markdown]
# ### Categorise batters by strike rate

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import StringType
from pyspark.sql.window import Window

spark=SparkSession.builder.appName("IPL_Performance").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)
ball_by_ball_df=spark.read.csv("/content/ball_by_ball_data.csv", header=True, inferSchema=True)

# Recalculate player_stats to get strike rate
player_stats = ball_by_ball_df.groupBy("batter").agg(
    sum("batter_runs").alias("Total_runs"),
    count("ball_number").alias("Faced_balls"),
    round((sum("batter_runs") / count("ball_number")) * 100, 2).alias("Strike_rate")
)

players_with_stats_df = players_df.join(player_stats, players_df["player_name"] == player_stats["batter"], "left")

# Categorise batters by Strike Rate
def rate_performance(sr):
  if sr is None:
      return "Unknown"
  elif sr >= 150:
    return "Explosive"
  elif sr >= 120:
    return "Aggressive"
  else:
    return "Controlled"

performance_udf = udf(rate_performance, StringType())

players_with_performance_df = players_with_stats_df.withColumn("Performance_category",
                                   performance_udf(col("Strike_rate")))
players_with_performance_df.show(truncate=False)
# Out:
# +---------+-------------+--------------+----------------------+---------+-------------------------+------------------+----------------------------------------------------------------------------------------------------+-------------+----------+-----------+-----------+--------------------+
# |player_id|player_name  |bat_style     |bowl_style            |field_pos|player_full_name         |player_name2      |player_image                                                                                        |batter       |Total_runs|Faced_balls|Strike_rate|Performance_category|
# +---------+-------------+--------------+----------------------+---------+-------------------------+------------------+----------------------------------------------------------------------------------------------------+-------------+----------+-----------+-----------+--------------------+
# |6730     |Mohsin Khan  |Left hand Bat |Left arm Medium fast  |NULL     |Mohsin Khan              |Mohsin Khan       |NULL                                                                                                |Mohsin Khan  |25        |27         |92.59      |Controlled          |
# |22       |Rashid Khan  |Right hand Bat|Legbreak Googly       |         |Rashid Khan Arman        |Rashid Khan       |https://www.espncricinfo.com/cricketers/rashid-khan-793463                                          |Rashid Khan  |585       |387        |151.16     |Explosive           |
# |590      |K Rabada     |Left hand Bat |Right arm Fast        |         |Kagiso Rabada            |Kagiso Rabada     |https://ipl-stats-sports-mechanic.s3.ap-south-1.amazonaws.com/ipl/playerimages/Kagiso%20Rabada.png  |K Rabada     |215       |216        |99.54      |Controlled          |
# |1424     |SN Khan      |Right hand Bat|Legbreak              |         |Sarfaraz Naushad Khan    |Sarfaraz Naushad  |NULL                                                                                                |SN Khan      |585       |456        |128.29     |Aggressive          |
# |963      |MN Samuels   |Right hand Bat|Right arm Offbreak    |         |Marlon Nathaniel Samuels |Marlon Nathaniel  |NULL                                                                                                |MN Samuels   |161       |174        |92.53      |Controlled          |
# |53       |SB Jakati    |Left hand Bat |Slow Left arm Orthodox|         |Shadab Bashir Jakati     |Shadab Bashir     |NULL                                                                                                |SB Jakati    |28        |30         |93.33      |Controlled          |
# |12       |DA Warner    |Left hand Bat |Legbreak              |         |David Andrew Warner      |David Andrew      |https://ipl-stats-sports-mechanic.s3.ap-south-1.amazonaws.com/ipl/playerimages/David%20Warner.png   |DA Warner    |6567      |4849       |135.43     |Aggressive          |
# |73       |MP Stoinis   |Right hand Bat|Right arm Medium      |         |Marcus Peter Stoinis     |Marcus Peter      |NULL                                                                                                |MP Stoinis   |2026      |1457       |139.05     |Aggressive          |
# |1119     |R Tewatia    |Left hand Bat |Legbreak              |         |Rahul Tewatia            |Rahul Tewatia     |https://www.espncricinfo.com/cricketers/rahul-tewatia-423838                                        |R Tewatia    |1112      |851        |130.67     |Aggressive          |
# |268      |RA Tripathi  |Right hand Bat|Right arm Medium      |         |Rahul Ajay Tripathi      |Rahul Ajay        |NULL                                                                                                |RA Tripathi  |2291      |1707       |134.21     |Aggressive          |
# |163      |RD Chahar    |Right hand Bat|Legbreak Googly       |         |Rahul Desraj Chahar      |Rahul Desraj      |NULL                                                                                                |RD Chahar    |129       |127        |101.57     |Controlled          |
# |186      |S Nadeem     |Right hand Bat|Slow Left arm Orthodox|         |Shahbaz Nadeem           |Shahbaz Nadeem    |NULL                                                                                                |S Nadeem     |39        |88         |44.32      |Controlled          |
# |59       |MK Pandey    |Right hand Bat|Right arm Medium      |         |Manish Krishnanand Pandey|Manish Krishnanand|NULL                                                                                                |MK Pandey    |3951      |3355       |117.76     |Controlled          |
# |531      |KS Williamson|Right hand Bat|Right arm Offbreak    |         |Kane Stuart Williamson   |Kane Stuart       |https://ipl-stats-sports-mechanic.s3.ap-south-1.amazonaws.com/ipl/playerimages/Kane%20Williamson.png|KS Williamson|2132      |1734       |122.95     |Aggressive          |
# |56       |G Gambhir    |Left hand Bat |Legbreak              |         |Gautam Gambhir           |Gautam Gambhir    |https://documents.iplt20.com/playerheadshot/ipl/284/84.png                                          |G Gambhir    |4217      |3524       |119.67     |Controlled          |
# |39       |MK Tiwary    |Right hand Bat|Legbreak Googly       |         |Manoj Kumar Tiwary       |Manoj Kumar       |NULL                                                                                                |MK Tiwary    |1695      |1489       |113.83     |Controlled          |
# |68       |M Vohra      |Right hand Bat|Right arm Medium      |         |Manan Vohra              |Manan Vohra       |NULL                                                                                                |M Vohra      |1083      |863        |125.49     |Aggressive          |
# |638      |NB Singh     |Right hand Bat|Right arm Medium      |         |Nathu Bharat Singh       |Nathu Bharat      |NULL                                                                                                |NULL         |NULL      |NULL       |NULL       |Unknown             |
# |40       |R Bhatia     |Right hand Bat|Right arm Medium fast |         |Rajat Bhatia             |Rajat Bhatia      |NULL                                                                                                |R Bhatia     |342       |290        |117.93     |Controlled          |
# |1233     |SS Tiwary    |Left hand Bat |                      |         |Saurabh Sunil Tiwary     |Saurabh Sunil     |NULL                                                                                                |SS Tiwary    |1494      |1291       |115.72     |Controlled          |
# +---------+-------------+--------------+----------------------+---------+-------------------------+------------------+----------------------------------------------------------------------------------------------------+-------------+----------+-----------+-----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Create UDF to classify bowlers by Economy Rate

# %%
bowler_stats = ball_by_ball_df.groupBy("bowler").agg(
    sum("total_runs").alias("Runs_Given"),
    count("ball_number").alias("Balls_Bowled")
).withColumn(
    "Economy_Rate", round(col("Runs_Given") / (col("Balls_Bowled") / 6), 2)
).filter(col("Balls_Bowled") > 0) # Filter out bowlers with 0 balls bowled to avoid division by zero

# 2. Join the bowler_stats with the players_df
# Assuming player_name in players_df corresponds to bowler in bowler_stats
players_with_bowler_stats_df = players_df.join(bowler_stats, players_df["player_name"] == bowler_stats["bowler"], "left")

# Define the UDF
def eco_zone(econ):
    if econ is None:
        return "Unknown"
    elif econ <= 6:
        return "Ultra-Economical"
    elif econ <= 8:
        return "Good"
    else:
        return "Expensive"

eco_udf = udf(eco_zone, StringType())

# Apply the UDF to the joined DataFrame
players_with_bowler_stats_df = players_with_bowler_stats_df.withColumn("Economy_Category",
                                   eco_udf(col("Economy_Rate")))

players_with_bowler_stats_df.select("player_name", "bowl_style", "Economy_Rate", "Economy_Category").show(10, truncate=False)
# Out:
# +-----------+----------------------+------------+----------------+
# |player_name|bowl_style            |Economy_Rate|Economy_Category|
# +-----------+----------------------+------------+----------------+
# |Mohsin Khan|Left arm Medium fast  |8.26        |Expensive       |
# |Rashid Khan|Legbreak Googly       |7.16        |Good            |
# |K Rabada   |Right arm Fast        |8.47        |Expensive       |
# |SN Khan    |Legbreak              |18.0        |Expensive       |
# |MN Samuels |Right arm Offbreak    |7.81        |Good            |
# |SB Jakati  |Slow Left arm Orthodox|8.03        |Expensive       |
# |DA Warner  |Legbreak              |6.0         |Ultra-Economical|
# |MP Stoinis |Right arm Medium      |9.61        |Expensive       |
# |R Tewatia  |Legbreak              |7.74        |Good            |
# |RA Tripathi|Right arm Medium      |12.0        |Expensive       |
# +-----------+----------------------+------------+----------------+
# only showing top 10 rows

# %% [markdown]
# ### 3. Flag star players using custom logic

# %%
# 1. Calculate Total Runs Scored and Matches Played by each player as a batter
player_batting_summary = ball_by_ball_df.groupBy("batter").agg(
    sum("batter_runs").alias("Total_Runs_Scored"),
    countDistinct("match_id").alias("Matches_Played")
)

dismissals_per_player = ball_by_ball_df.filter(col("player_out").isNotNull()) \
                                         .groupBy("player_out") \
                                         .agg(count("*").alias("Dismissals")) \
                                         .withColumnRenamed("player_out", "batter_dismissed_name")

# 3. Join batting summary with dismissals
player_batting_stats = player_batting_summary.join(
    dismissals_per_player,
    player_batting_summary["batter"] == dismissals_per_player["batter_dismissed_name"],
    "left_outer"
).drop("batter_dismissed_name")

player_batting_stats = player_batting_stats \
    .withColumn("Dismissals", when(col("Dismissals").isNull(), lit(0)).otherwise(col("Dismissals")).cast("long")) \
    .na.fill(0, ["Total_Runs_Scored", "Matches_Played"]) # Fill nulls for players who never batted/no data

# 5. Calculate Batting Average, handling cases with zero dismissals
player_batting_stats = player_batting_stats.withColumn(
    "Batting_Average",
    when(col("Dismissals") > 0, round(col("Total_Runs_Scored") / col("Dismissals"), 2)).otherwise(col("Total_Runs_Scored"))
)

# 6. Join these calculated stats with the main players_df
players_with_advanced_stats_df = players_df.join(
    player_batting_stats,
    players_df["player_name"] == player_batting_stats["batter"],
    "left"
).drop("batter") # Drop the duplicate 'batter' column

# Define the UDF for star player logic
def star_player_logic(avg, matches):
    if avg is None or matches is None:
        return " Unknown" # Players with no batting data
    return " Star" if avg >= 40 and matches >= 50 else " Normal"

star_udf = udf(star_player_logic, StringType())

# 7. Apply the UDF to the combined DataFrame
players_with_star_status_df = players_with_advanced_stats_df.withColumn("Star_Status",
                                   star_udf(col("Batting_Average"),
                                            col("Matches_Played")))

# Show relevant columns
players_with_star_status_df.select("player_name", "Total_Runs_Scored", "Matches_Played", "Dismissals", "Batting_Average", "Star_Status").show(10, truncate=False)
# Out:
# +-----------+-----------------+--------------+----------+---------------+-----------+
# |player_name|Total_Runs_Scored|Matches_Played|Dismissals|Batting_Average|Star_Status|
# +-----------+-----------------+--------------+----------+---------------+-----------+
# |Mohsin Khan|25               |5             |3         |8.33           | Normal    |
# |Rashid Khan|585              |66            |42        |13.93          | Normal    |
# |K Rabada   |215              |30            |18        |11.94          | Normal    |
# |SN Khan    |585              |36            |26        |22.5           | Normal    |
# |MN Samuels |161              |14            |13        |12.38          | Normal    |
# |SB Jakati  |28               |5             |1         |28.0           | Normal    |
# |DA Warner  |6567             |184           |164       |40.04          | Star      |
# |MP Stoinis |2026             |99            |72        |28.14          | Normal    |
# |R Tewatia  |1112             |76            |48        |23.17          | Normal    |
# |RA Tripathi|2291             |98            |88        |26.03          | Normal    |
# +-----------+-----------------+--------------+----------+---------------+-----------+
# only showing top 10 rows

# %% [markdown]
# ### 4.Add Role-based classification

# %%
from pyspark.sql.functions import col, sum, count, countDistinct, when, round, lit, udf
from pyspark.sql.types import StringType

# Ensure SparkSession and DataFrames are loaded if this cell is run independently
spark=SparkSession.builder.appName("IPL_Performance").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)
ball_by_ball_df=spark.read.csv("/content/ball_by_ball_data.csv", header=True, inferSchema=True)

# 1. Calculate Batting Statistics (Total Runs, Matches Played, Dismissals, Batting Average)
player_batting_summary = ball_by_ball_df.groupBy("batter").agg(
    sum("batter_runs").alias("Total_Runs_Scored"),
    countDistinct("match_id").alias("Matches_Played")
)
dismissals_per_player = ball_by_ball_df.filter(col("player_out").isNotNull()) \
                                         .groupBy("player_out") \
                                         .agg(count("*").alias("Dismissals")) \
                                         .withColumnRenamed("player_out", "batter_dismissed_name")

player_batting_stats = player_batting_summary.join(
    dismissals_per_player,
    player_batting_summary["batter"] == dismissals_per_player["batter_dismissed_name"],
    "left_outer"
).drop("batter_dismissed_name")

player_batting_stats = player_batting_stats \
    .withColumn("Dismissals", when(col("Dismissals").isNull(), lit(0)).otherwise(col("Dismissals")).cast("long")) \
    .na.fill(0, ["Total_Runs_Scored", "Matches_Played"])

player_batting_stats = player_batting_stats.withColumn(
    "Batting_Average",
    when(col("Dismissals") > 0, round(col("Total_Runs_Scored") / col("Dismissals"), 2)).otherwise(col("Total_Runs_Scored"))
)

# Join base players_df with batting stats
players_with_batting_stats_df = players_df.join(
    player_batting_stats,
    players_df["player_name"] == player_batting_stats["batter"],
    "left"
).drop("batter")

# 2. Calculate Bowling Statistics (Runs Conceded, Wickets Taken, Bowling Average)
bowler_stats_for_role = ball_by_ball_df.groupBy("bowler").agg(
    sum(col("total_runs")).alias("Runs_Conceded"),
    sum(when((col("is_wicket") == "True") & (col("wicket_kind") != "run out"), 1).otherwise(0)).alias("Wickets_Taken")
)

bowler_stats_for_role = bowler_stats_for_role.withColumn(
    "Bowling_Average",
    when(col("Wickets_Taken") > 0, round(col("Runs_Conceded") / col("Wickets_Taken"), 2)).otherwise(lit(None))
)

# 3. Join batting and bowling statistics with the players_df
final_players_df = players_with_batting_stats_df.join(
    bowler_stats_for_role,
    players_with_batting_stats_df["player_name"] == bowler_stats_for_role["bowler"],
    "left"
).drop("bowler") # Drop the duplicate 'bowler' column

# 4. Define the UDF for role classification
def identify_role(bat_avg, bowl_avg):
    if bat_avg is None and bowl_avg is None:
        return "Unknown"

    # Handle players who only bat or only bowl (no meaningful stats for the other)
    if (bat_avg is None or bat_avg == 0) and (bowl_avg is not None and bowl_avg != float('inf') and bowl_avg > 0):
        return "Bowler"
    if (bowl_avg is None or bowl_avg == float('inf')) and (bat_avg is not None and bat_avg > 0):
        return "Batter"

    # For players with both stats, compare their relative strengths using thresholds
    is_good_batter = bat_avg is not None and bat_avg >= 25 # Threshold for good batting average
    is_good_bowler = bowl_avg is not None and bowl_avg <= 30 and bowl_avg > 0 # Threshold for good bowling average

    if is_good_batter and is_good_bowler:
        return "All-Rounder"
    elif is_good_batter:
        return "Batter"
    elif is_good_bowler:
        return "Bowler"
    else:
        return "Other" # Neither particularly good at batting nor bowling by these thresholds

role_udf = udf(identify_role, StringType())

# 5. Apply the UDF to the final_players_df
players_with_role_df = final_players_df.withColumn("Role_Type",
                                   role_udf(col("Batting_Average"),
                                            col("Bowling_Average")))

# Show relevant columns
players_with_role_df.select(
    "player_name", "Batting_Average", "Total_Runs_Scored", "Matches_Played", "Dismissals",
    "Bowling_Average", "Runs_Conceded", "Wickets_Taken", "Role_Type"
).show(10, truncate=False)
# Out:
# +-----------+---------------+-----------------+--------------+----------+---------------+-------------+-------------+---------+
# |player_name|Batting_Average|Total_Runs_Scored|Matches_Played|Dismissals|Bowling_Average|Runs_Conceded|Wickets_Taken|Role_Type|
# +-----------+---------------+-----------------+--------------+----------+---------------+-------------+-------------+---------+
# |Mohsin Khan|8.33           |25               |5             |3         |NULL           |698          |0            |Batter   |
# |Rashid Khan|13.93          |585              |66            |42        |NULL           |3863         |0            |Batter   |
# |K Rabada   |11.94          |215              |30            |18        |NULL           |2816         |0            |Batter   |
# |SN Khan    |22.5           |585              |36            |26        |NULL           |6            |0            |Batter   |
# |MN Samuels |12.38          |161              |14            |13        |NULL           |285          |0            |Batter   |
# |SB Jakati  |28.0           |28               |5             |1         |NULL           |1474         |0            |Batter   |
# |DA Warner  |40.04          |6567             |184           |164       |NULL           |2            |0            |Batter   |
# |MP Stoinis |28.14          |2026             |99            |72        |NULL           |1477         |0            |Batter   |
# |R Tewatia  |23.17          |1112             |76            |48        |NULL           |1117         |0            |Batter   |
# |RA Tripathi|26.03          |2291             |98            |88        |NULL           |12           |0            |Batter   |
# +-----------+---------------+-----------------+--------------+----------+---------------+-------------+-------------+---------+
# only showing top 10 rows

# %% [markdown]
# # **44.PySpark Pandas UDF (Vectorized UDF)**

# %% [markdown]
# ### Clssify players performance using Pandas UDF

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import StringType
from pyspark.sql.window import Window
import pandas as pd

spark=SparkSession.builder.appName("IPL_Performance").getOrCreate()
matches_df=spark.read.csv("/content/ipl_matches_data.csv", header=True, inferSchema=True)
players_df=spark.read.csv("/content/players-data-updated.csv", header=True, inferSchema=True)
teams_df=spark.read.csv("/content/teams_data.csv", header=True, inferSchema=True)
ball_by_ball_df=spark.read.csv("/content/ball_by_ball_data.csv", header=True, inferSchema=True)

# Recalculate player_stats to get strike rate, similar to previous cells
player_stats = ball_by_ball_df.groupBy("batter").agg(
    sum("batter_runs").alias("Total_runs"),
    count("ball_number").alias("Faced_balls"),
    round((sum("batter_runs") / count("ball_number")) * 100, 2).alias("Strike_rate")
).filter(col("Faced_balls") > 0) # Filter to avoid division by zero for Strike_rate

# Join players_df with player_stats to get the Strike_rate
players_with_stats_df = players_df.join(player_stats, players_df["player_name"] == player_stats["batter"], "left")

@pandas_udf("string")
def performance_category(sr: pd.Series) -> pd.Series:
  return sr.apply(lambda x: "Elite" if x >= 150 else("Good" if x >= 120 else "Average"))

# Apply the UDF to the DataFrame that now contains the 'Strike_rate' column
players_with_performance_df_pandas_udf = players_with_stats_df.withColumn("Performance_category",
                                   performance_category(players_with_stats_df.Strike_rate))
players_with_performance_df_pandas_udf.show(truncate=False)
# Out:
# +---------+-------------+--------------+----------------------+---------+-------------------------+------------------+----------------------------------------------------------------------------------------------------+-------------+----------+-----------+-----------+--------------------+
# |player_id|player_name  |bat_style     |bowl_style            |field_pos|player_full_name         |player_name2      |player_image                                                                                        |batter       |Total_runs|Faced_balls|Strike_rate|Performance_category|
# +---------+-------------+--------------+----------------------+---------+-------------------------+------------------+----------------------------------------------------------------------------------------------------+-------------+----------+-----------+-----------+--------------------+
# |6730     |Mohsin Khan  |Left hand Bat |Left arm Medium fast  |NULL     |Mohsin Khan              |Mohsin Khan       |NULL                                                                                                |Mohsin Khan  |25        |27         |92.59      |Average             |
# |22       |Rashid Khan  |Right hand Bat|Legbreak Googly       |         |Rashid Khan Arman        |Rashid Khan       |https://www.espncricinfo.com/cricketers/rashid-khan-793463                                          |Rashid Khan  |585       |387        |151.16     |Elite               |
# |590      |K Rabada     |Left hand Bat |Right arm Fast        |         |Kagiso Rabada            |Kagiso Rabada     |https://ipl-stats-sports-mechanic.s3.ap-south-1.amazonaws.com/ipl/playerimages/Kagiso%20Rabada.png  |K Rabada     |215       |216        |99.54      |Average             |
# |1424     |SN Khan      |Right hand Bat|Legbreak              |         |Sarfaraz Naushad Khan    |Sarfaraz Naushad  |NULL                                                                                                |SN Khan      |585       |456        |128.29     |Good                |
# |963      |MN Samuels   |Right hand Bat|Right arm Offbreak    |         |Marlon Nathaniel Samuels |Marlon Nathaniel  |NULL                                                                                                |MN Samuels   |161       |174        |92.53      |Average             |
# |53       |SB Jakati    |Left hand Bat |Slow Left arm Orthodox|         |Shadab Bashir Jakati     |Shadab Bashir     |NULL                                                                                                |SB Jakati    |28        |30         |93.33      |Average             |
# |12       |DA Warner    |Left hand Bat |Legbreak              |         |David Andrew Warner      |David Andrew      |https://ipl-stats-sports-mechanic.s3.ap-south-1.amazonaws.com/ipl/playerimages/David%20Warner.png   |DA Warner    |6567      |4849       |135.43     |Good                |
# |73       |MP Stoinis   |Right hand Bat|Right arm Medium      |         |Marcus Peter Stoinis     |Marcus Peter      |NULL                                                                                                |MP Stoinis   |2026      |1457       |139.05     |Good                |
# |1119     |R Tewatia    |Left hand Bat |Legbreak              |         |Rahul Tewatia            |Rahul Tewatia     |https://www.espncricinfo.com/cricketers/rahul-tewatia-423838                                        |R Tewatia    |1112      |851        |130.67     |Good                |
# |268      |RA Tripathi  |Right hand Bat|Right arm Medium      |         |Rahul Ajay Tripathi      |Rahul Ajay        |NULL                                                                                                |RA Tripathi  |2291      |1707       |134.21     |Good                |
# |163      |RD Chahar    |Right hand Bat|Legbreak Googly       |         |Rahul Desraj Chahar      |Rahul Desraj      |NULL                                                                                                |RD Chahar    |129       |127        |101.57     |Average             |
# |186      |S Nadeem     |Right hand Bat|Slow Left arm Orthodox|         |Shahbaz Nadeem           |Shahbaz Nadeem    |NULL                                                                                                |S Nadeem     |39        |88         |44.32      |Average             |
# |59       |MK Pandey    |Right hand Bat|Right arm Medium      |         |Manish Krishnanand Pandey|Manish Krishnanand|NULL                                                                                                |MK Pandey    |3951      |3355       |117.76     |Average             |
# |531      |KS Williamson|Right hand Bat|Right arm Offbreak    |         |Kane Stuart Williamson   |Kane Stuart       |https://ipl-stats-sports-mechanic.s3.ap-south-1.amazonaws.com/ipl/playerimages/Kane%20Williamson.png|KS Williamson|2132      |1734       |122.95     |Good                |
# |56       |G Gambhir    |Left hand Bat |Legbreak              |         |Gautam Gambhir           |Gautam Gambhir    |https://documents.iplt20.com/playerheadshot/ipl/284/84.png                                          |G Gambhir    |4217      |3524       |119.67     |Average             |
# |39       |MK Tiwary    |Right hand Bat|Legbreak Googly       |         |Manoj Kumar Tiwary       |Manoj Kumar       |NULL                                                                                                |MK Tiwary    |1695      |1489       |113.83     |Average             |
# |68       |M Vohra      |Right hand Bat|Right arm Medium      |         |Manan Vohra              |Manan Vohra       |NULL                                                                                                |M Vohra      |1083      |863        |125.49     |Good                |
# |638      |NB Singh     |Right hand Bat|Right arm Medium      |         |Nathu Bharat Singh       |Nathu Bharat      |NULL                                                                                                |NULL         |NULL      |NULL       |NULL       |Average             |
# |40       |R Bhatia     |Right hand Bat|Right arm Medium fast |         |Rajat Bhatia             |Rajat Bhatia      |NULL                                                                                                |R Bhatia     |342       |290        |117.93     |Average             |
# |1233     |SS Tiwary    |Left hand Bat |                      |         |Saurabh Sunil Tiwary     |Saurabh Sunil     |NULL                                                                                                |SS Tiwary    |1494      |1291       |115.72     |Average             |
# +---------+-------------+--------------+----------------------+---------+-------------------------+------------------+----------------------------------------------------------------------------------------------------+-------------+----------+-----------+-----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### 2. Compute average strike rate for group using vevtorised function.

# %%
@pandas_udf("double")
def avg_strike_rate(sr: pd.Series) -> float:
  return sr.mean()
players_with_stats_df.groupBy("bat_style").agg(avg_strike_rate(col("Strike_rate")).alias("Average_Strike_Rate")).show()
# Out:
# +--------------+-------------------+
# |     bat_style|Average_Strike_Rate|
# +--------------+-------------------+
# | Left hand Bat|  109.7942564102564|
# |Right hand Bat| 100.83720472440946|
# +--------------+-------------------+

# %% [markdown]
# ### 3. Classify bolwers using Pandas UDF

# %%
bowler_stats = ball_by_ball_df.groupBy("bowler").agg(
    sum("total_runs").alias("Runs_Given"),
    count("ball_number").alias("Balls_Bowled")
).withColumn(
    "Economy_Rate", round(col("Runs_Given") / (col("Balls_Bowled") / 6), 2)
).filter(col("Balls_Bowled") > 0)

players_with_bowler_stats_df = players_df.join(bowler_stats, players_df["player_name"] == bowler_stats["bowler"], "left")

@pandas_udf("string")
def eco_category(econ: pd.Series) -> pd.Series:
  return econ.apply(lambda x: "Economical" if x <=6 else("Medium" if x <=8 else "Expensive"))

players_with_economy_category = players_with_bowler_stats_df.withColumn("Economy_Zone", eco_category(players_with_bowler_stats_df.Economy_Rate))
players_with_economy_category.select("player_name", "bowl_style", "Economy_Rate", "Economy_Zone").show(10, truncate=False)
# Out:
# +-----------+----------------------+------------+------------+
# |player_name|bowl_style            |Economy_Rate|Economy_Zone|
# +-----------+----------------------+------------+------------+
# |Mohsin Khan|Left arm Medium fast  |8.26        |Expensive   |
# |Rashid Khan|Legbreak Googly       |7.16        |Medium      |
# |K Rabada   |Right arm Fast        |8.47        |Expensive   |
# |SN Khan    |Legbreak              |18.0        |Expensive   |
# |MN Samuels |Right arm Offbreak    |7.81        |Medium      |
# |SB Jakati  |Slow Left arm Orthodox|8.03        |Expensive   |
# |DA Warner  |Legbreak              |6.0         |Economical  |
# |MP Stoinis |Right arm Medium      |9.61        |Expensive   |
# |R Tewatia  |Legbreak              |7.74        |Medium      |
# |RA Tripathi|Right arm Medium      |12.0        |Expensive   |
# +-----------+----------------------+------------+------------+
# only showing top 10 rows

# %% [markdown]
# ### 4. Calculate score impact factor

# %%
@pandas_udf("string")
def short_id(name: pd.Series) -> pd.Series:
    return name.apply(lambda x: "".join([n[0] for n in x.split()]).upper())

players_df = players_df.withColumn("Short_ID", short_id(players_df.player_name))
players_df.show()
# Out:
# +---------+-------------+--------------+--------------------+---------+--------------------+------------------+--------------------+--------+
# |player_id|  player_name|     bat_style|          bowl_style|field_pos|    player_full_name|      player_name2|        player_image|Short_ID|
# +---------+-------------+--------------+--------------------+---------+--------------------+------------------+--------------------+--------+
# |     6730|  Mohsin Khan| Left hand Bat|Left arm Medium fast|     NULL|         Mohsin Khan|       Mohsin Khan|                NULL|      MK|
# |       22|  Rashid Khan|Right hand Bat|     Legbreak Googly|         |   Rashid Khan Arman|       Rashid Khan|https://www.espnc...|      RK|
# |      590|     K Rabada| Left hand Bat|      Right arm Fast|         |       Kagiso Rabada|     Kagiso Rabada|https://ipl-stats...|      KR|
# |     1424|      SN Khan|Right hand Bat|            Legbreak|         |Sarfaraz Naushad ...|  Sarfaraz Naushad|                NULL|      SK|
# |      963|   MN Samuels|Right hand Bat|  Right arm Offbreak|         |Marlon Nathaniel ...|  Marlon Nathaniel|                NULL|      MS|
# |       53|    SB Jakati| Left hand Bat|Slow Left arm Ort...|         |Shadab Bashir Jakati|     Shadab Bashir|                NULL|      SJ|
# |       12|    DA Warner| Left hand Bat|            Legbreak|         | David Andrew Warner|      David Andrew|https://ipl-stats...|      DW|
# |       73|   MP Stoinis|Right hand Bat|    Right arm Medium|         |Marcus Peter Stoinis|      Marcus Peter|                NULL|      MS|
# |     1119|    R Tewatia| Left hand Bat|            Legbreak|         |       Rahul Tewatia|     Rahul Tewatia|https://www.espnc...|      RT|
# |      268|  RA Tripathi|Right hand Bat|    Right arm Medium|         | Rahul Ajay Tripathi|        Rahul Ajay|                NULL|      RT|
# |      163|    RD Chahar|Right hand Bat|     Legbreak Googly|         | Rahul Desraj Chahar|      Rahul Desraj|                NULL|      RC|
# |      186|     S Nadeem|Right hand Bat|Slow Left arm Ort...|         |      Shahbaz Nadeem|    Shahbaz Nadeem|                NULL|      SN|
# |       59|    MK Pandey|Right hand Bat|    Right arm Medium|         |Manish Krishnanan...|Manish Krishnanand|                NULL|      MP|
# |      531|KS Williamson|Right hand Bat|  Right arm Offbreak|         |Kane Stuart Willi...|       Kane Stuart|https://ipl-stats...|      KW|
# |       56|    G Gambhir| Left hand Bat|            Legbreak|         |      Gautam Gambhir|    Gautam Gambhir|https://documents...|      GG|
# |       39|    MK Tiwary|Right hand Bat|     Legbreak Googly|         |  Manoj Kumar Tiwary|       Manoj Kumar|                NULL|      MT|
# |       68|      M Vohra|Right hand Bat|    Right arm Medium|         |         Manan Vohra|       Manan Vohra|                NULL|      MV|
# |      638|     NB Singh|Right hand Bat|    Right arm Medium|         |  Nathu Bharat Singh|      Nathu Bharat|                NULL|      NS|
# |       40|     R Bhatia|Right hand Bat|Right arm Medium ...|         |        Rajat Bhatia|      Rajat Bhatia|                NULL|      RB|
# |     1233|    SS Tiwary| Left hand Bat|                    |         |Saurabh Sunil Tiwary|     Saurabh Sunil|                NULL|      ST|
# +---------+-------------+--------------+--------------------+---------+--------------------+------------------+--------------------+--------+
# only showing top 20 rows
